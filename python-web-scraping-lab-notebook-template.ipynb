# %% [markdown]
# # Web Scraping in Python (EoC I, F21)

# %% [markdown]
# Student Name: Joseph Neus
# <br>
# Net ID: 902039137
# <br>

# %% [markdown]
# NOTE: Remember to submit two versions of your lab notebook on Canvas- a Jupyter Notebook (`.ipynb`) file and a PDF.

# %% [markdown]
# **Q1: Describe the general approach to loading a web page in Python using `requests` and isolating the section of HTML you need using `BeautifulSoup`. What are the basic steps involved in this workflow, thinking about what happens at the start of the program to isolate the section of HTML you would need to do further work with to extract the data you want to work with?**

# %% [markdown]
# **Answer**: In order to use beautiful soup we use requests library. To load a URL, we use requests.get which is a method within the requests library with the URL of the webpage that we assign to a variable. We then create a beautifulsoup object to interact with the webpage content. With the beautifulsoup object we have a variable which is assigned to beautiful soup library using the previous page and format it as text and parse it as html. To find the single instance of the html tag we can use .find() while .find_all() creates a list-like object with each instance of a specific tag. There is also index operators that can go through the items in tables to indicate which one has the HTML we would work with.

# %% [markdown]
# **Q2: Select another Wikipedia page that includes a table. From looking at the public web page, what data do you want to scrape from this web page (i.e. specific table, multiple tables, etc.)? What do you want the resulting data structure to look like (columns, rows, etc)?**

# %% [markdown]
# **Answer**: I chose to do the United Nations wiki page (https://en.wikipedia.org/wiki/United_Nations). For this Wikipedia page, I want to scrape a table called the Secretaries-General of the UN. For this table, I want the resulting data structure with columns that will include a number (order of job position), name, country of origin, when they took office, when they left office, as well as extra notes. There will also be nine rows as there are nine secretaries.

# %% [markdown]
# Number,
# Name,
# Country of Origin,
# When They Took Office,
# When They Left Office,
# Extra Notes

# %%
# your codes here (if needed)

# %% [markdown]
# **Q3: Take a look at the HTML for this page. What tags or other HTML components do you see around the section of the page you want to work with? For this question, we're thinking about how we will end up writing a program with <code>BeautifulSoup</code> to isolate a section of the web page.**

# %% [markdown]
# **Answer**: Looking at the section of the page I want to work with, I see tags such as <th> and <tr> for table heading and rows. More specifically, I see tags such as <table class="wikitable" style="font-size:90%; text-align:left;"> This marks the start of the table. There is also class="flagicon" which is attributed to table rows. These are some clues that may be used for the BeautifulSoup to isolate the section of the webpage.

# %%
# your codes here (if needed)

# %% [markdown]
# <strong>Q4: Develop an outline for a Python program that scrapes data from the web page you selected.
#
# A preliminary workflow:
# - Load URL and create BeautifulSoup object
# - Isolate section of HTML with your table (either directly or extract from list)
# - Isolate table row elements (create list where each element is a table row)
# - Extract contents from row (isolate the pieces of information from each row)
# - Write extracted row contents to CSV file
#
# NOTE: You do not need to have working code for all components of this program. That's where we're heading with the final project. At this point, we're focusing on the conceptual framework for the web scraping program. Start to build out code where you can, but think about the programming version of outlining a paper.</strong>

# %% [markdown]
# **Answer**: I first imported libraries. I then used get page to get the United Nations link. After that, I created beautifulsoup object and isolated all html using wikitable class. I indicated which table I wanted the program to focus on and then I got all table rows from the secretary_table.

# %%
import requests
from bs4 import BeautifulSoup
import csv
import pandas as pd

# %%
page = requests.get('https://en.wikipedia.org/wiki/United_Nations')
soup = BeautifulSoup(page.text, 'html.parser')

# %%
tables = soup.find_all(class_ = 'wikitable')

# %%
tables[0]
# Out:
# <table class="wikitable" style="font-size:90%; text-align:left;">
# <caption style="padding-top:1em;">Secretaries-General of the United Nations<sup class="reference" id="cite_ref-115"><a href="#cite_note-115">[114]</a></sup>
# </caption>
# <tbody><tr>
# <th>No.</th>
# <th>Name</th>
# <th>Country of origin</th>
# <th>Took office</th>
# <th>Left office</th>
# <th>Notes
# </th></tr>
# <tr>
# <td>-
# </td>
# <td><b><a href="/wiki/Gladwyn_Jebb" title="Gladwyn Jebb">Gladwyn Jebb</a></b>
# </td>
# <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="1200" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/en/thumb/a/ae/Flag_of_the_United_Kingdom.svg/23px-Flag_of_the_United_Kingdom.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/a/ae/Flag_of_the_United_Kingdom.svg/35px-Flag_of_the_United_Kingdom.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/a/ae/Flag_of_the_United_Kingdom.svg/46px-Flag_of_the_United_Kingdom.svg.png 2x" width="23"/> </span><a href="/wiki/United_Kingdom" title="United Kingdom">United Kingdom</a>
# </td>
# <td>24 October 1945
# </td>
# <td>2 February 1946
# </td>
# <td>Served as <a href="/wiki/Acting_(law)" title="Acting (law)">Acting</a> Secretary-General until Lie's election
# </td></tr>
# <tr>
# <td>1</td>
# <td><b><a href="/wiki/Trygve_Lie" title="Trygve Lie">Trygve Lie</a></b></td>
# <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="372" data-file-width="512" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/d9/Flag_of_Norway.svg/21px-Flag_of_Norway.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/d9/Flag_of_Norway.svg/32px-Flag_of_Norway.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/d9/Flag_of_Norway.svg/41px-Flag_of_Norway.svg.png 2x" width="21"/> </span><a href="/wiki/Norway" title="Norway">Norway</a></td>
# <td>2 February 1946</td>
# <td>10 November 1952</td>
# <td>Resigned
# </td></tr>
# <tr>
# <td>2</td>
# <td><b><a href="/wiki/Dag_Hammarskj%C3%B6ld" title="Dag Hammarskjöld">Dag Hammarskjöld</a></b></td>
# <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="1000" data-file-width="1600" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/en/thumb/4/4c/Flag_of_Sweden.svg/23px-Flag_of_Sweden.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/4/4c/Flag_of_Sweden.svg/35px-Flag_of_Sweden.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/4/4c/Flag_of_Sweden.svg/46px-Flag_of_Sweden.svg.png 2x" width="23"/> </span><a href="/wiki/Sweden" title="Sweden">Sweden</a></td>
# <td>10 April 1953</td>
# <td>18 September 1961</td>
# <td>Died in office
# </td></tr>
# <tr>
# <td>3</td>
# <td><b><a href="/wiki/U_Thant" title="U Thant">U Thant</a></b></td>
# <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="500" data-file-width="900" decoding="async" height="13" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/51/Flag_of_Burma_%281948%E2%80%931974%29.svg/23px-Flag_of_Burma_%281948%E2%80%931974%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/51/Flag_of_Burma_%281948%E2%80%931974%29.svg/35px-Flag_of_Burma_%281948%E2%80%931974%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/51/Flag_of_Burma_%281948%E2%80%931974%29.svg/46px-Flag_of_Burma_%281948%E2%80%931974%29.svg.png 2x" width="23"/> </span><a href="/wiki/Myanmar" title="Myanmar">Burma</a></td>
# <td>30 November 1961</td>
# <td>31 December 1971</td>
# <td>First non-European to hold office
# </td></tr>
# <tr>
# <td>4</td>
# <td><b><a href="/wiki/Kurt_Waldheim" title="Kurt Waldheim">Kurt Waldheim</a></b></td>
# <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/41/Flag_of_Austria.svg/23px-Flag_of_Austria.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/41/Flag_of_Austria.svg/35px-Flag_of_Austria.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/41/Flag_of_Austria.svg/45px-Flag_of_Austria.svg.png 2x" width="23"/> </span><a href="/wiki/Austria" title="Austria">Austria</a></td>
# <td>1 January 1972</td>
# <td>31 December 1981</td>
# <td>
# </td></tr>
# <tr>
# <td>5</td>
# <td><b><a href="/wiki/Javier_P%C3%A9rez_de_Cu%C3%A9llar" title="Javier Pérez de Cuéllar">Javier Pérez de Cuéllar</a></b></td>
# <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/c/cf/Flag_of_Peru.svg/23px-Flag_of_Peru.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/c/cf/Flag_of_Peru.svg/35px-Flag_of_Peru.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/c/cf/Flag_of_Peru.svg/45px-Flag_of_Peru.svg.png 2x" width="23"/> </span><a href="/wiki/Peru" title="Peru">Peru</a></td>
# <td>1 January 1982</td>
# <td>31 December 1991</td>
# <td>
# </td></tr>
# <tr>
# <td>6</td>
# <td><b><a href="/wiki/Boutros_Boutros-Ghali" title="Boutros Boutros-Ghali">Boutros Boutros-Ghali</a></b></td>
# <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/fe/Flag_of_Egypt.svg/23px-Flag_of_Egypt.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/fe/Flag_of_Egypt.svg/35px-Flag_of_Egypt.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/fe/Flag_of_Egypt.svg/45px-Flag_of_Egypt.svg.png 2x" width="23"/> </span><a href="/wiki/Egypt" title="Egypt">Egypt</a></td>
# <td>1 January 1992</td>
# <td>31 December 1996</td>
# <td>Served for the shortest time
# </td></tr>
# <tr>
# <td>7</td>
# <td><b><a href="/wiki/Kofi_Annan" title="Kofi Annan">Kofi Annan</a></b></td>
# <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/19/Flag_of_Ghana.svg/23px-Flag_of_Ghana.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/19/Flag_of_Ghana.svg/35px-Flag_of_Ghana.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/19/Flag_of_Ghana.svg/45px-Flag_of_Ghana.svg.png 2x" width="23"/> </span><a href="/wiki/Ghana" title="Ghana">Ghana</a></td>
# <td>1 January 1997</td>
# <td>31 December 2006</td>
# <td>
# </td></tr>
# <tr>
# <td>8</td>
# <td><b><a href="/wiki/Ban_Ki-moon" title="Ban Ki-moon">Ban Ki-moon</a></b></td>
# <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/09/Flag_of_South_Korea.svg/23px-Flag_of_South_Korea.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/09/Flag_of_South_Korea.svg/35px-Flag_of_South_Korea.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/0/09/Flag_of_South_Korea.svg/45px-Flag_of_South_Korea.svg.png 2x" width="23"/> </span><a href="/wiki/South_Korea" title="South Korea">South Korea</a></td>
# <td>1 January 2007</td>
# <td>31 December 2016</td>
# <td>
# </td></tr>
# <tr>
# <td>9</td>
# <td><b><a href="/wiki/Ant%C3%B3nio_Guterres" title="António Guterres">António Guterres</a></b></td>
# <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="400" data-file-width="600" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/5c/Flag_of_Portugal.svg/23px-Flag_of_Portugal.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/5c/Flag_of_Portugal.svg/35px-Flag_of_Portugal.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/5c/Flag_of_Portugal.svg/45px-Flag_of_Portugal.svg.png 2x" width="23"/> </span><a href="/wiki/Portugal" title="Portugal">Portugal</a></td>
# <td>1 January 2017</td>
# <td><i>Incumbent</i></td>
# <td>
# </td></tr></tbody></table>

# %%
secretary_table = tables[0]

# %%
secretary_test = secretary_table.find_all("tr")
secretary_test
# Out:
# [<tr>
#  <th>No.</th>
#  <th>Name</th>
#  <th>Country of origin</th>
#  <th>Took office</th>
#  <th>Left office</th>
#  <th>Notes
#  </th></tr>,
#  <tr>
#  <td>-
#  </td>
#  <td><b><a href="/wiki/Gladwyn_Jebb" title="Gladwyn Jebb">Gladwyn Jebb</a></b>
#  </td>
#  <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="1200" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/en/thumb/a/ae/Flag_of_the_United_Kingdom.svg/23px-Flag_of_the_United_Kingdom.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/a/ae/Flag_of_the_United_Kingdom.svg/35px-Flag_of_the_United_Kingdom.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/a/ae/Flag_of_the_United_Kingdom.svg/46px-Flag_of_the_United_Kingdom.svg.png 2x" width="23"/> </span><a href="/wiki/United_Kingdom" title="United Kingdom">United Kingdom</a>
#  </td>
#  <td>24 October 1945
#  </td>
#  <td>2 February 1946
#  </td>
#  <td>Served as <a href="/wiki/Acting_(law)" title="Acting (law)">Acting</a> Secretary-General until Lie's election
#  </td></tr>,
#  <tr>
#  <td>1</td>
#  <td><b><a href="/wiki/Trygve_Lie" title="Trygve Lie">Trygve Lie</a></b></td>
#  <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="372" data-file-width="512" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/d9/Flag_of_Norway.svg/21px-Flag_of_Norway.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/d9/Flag_of_Norway.svg/32px-Flag_of_Norway.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/d9/Flag_of_Norway.svg/41px-Flag_of_Norway.svg.png 2x" width="21"/> </span><a href="/wiki/Norway" title="Norway">Norway</a></td>
#  <td>2 February 1946</td>
#  <td>10 November 1952</td>
#  <td>Resigned
#  </td></tr>,
#  <tr>
#  <td>2</td>
#  <td><b><a href="/wiki/Dag_Hammarskj%C3%B6ld" title="Dag Hammarskjöld">Dag Hammarskjöld</a></b></td>
#  <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="1000" data-file-width="1600" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/en/thumb/4/4c/Flag_of_Sweden.svg/23px-Flag_of_Sweden.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/4/4c/Flag_of_Sweden.svg/35px-Flag_of_Sweden.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/4/4c/Flag_of_Sweden.svg/46px-Flag_of_Sweden.svg.png 2x" width="23"/> </span><a href="/wiki/Sweden" title="Sweden">Sweden</a></td>
#  <td>10 April 1953</td>
#  <td>18 September 1961</td>
#  <td>Died in office
#  </td></tr>,
#  <tr>
#  <td>3</td>
#  <td><b><a href="/wiki/U_Thant" title="U Thant">U Thant</a></b></td>
#  <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="500" data-file-width="900" decoding="async" height="13" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/51/Flag_of_Burma_%281948%E2%80%931974%29.svg/23px-Flag_of_Burma_%281948%E2%80%931974%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/51/Flag_of_Burma_%281948%E2%80%931974%29.svg/35px-Flag_of_Burma_%281948%E2%80%931974%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/51/Flag_of_Burma_%281948%E2%80%931974%29.svg/46px-Flag_of_Burma_%281948%E2%80%931974%29.svg.png 2x" width="23"/> </span><a href="/wiki/Myanmar" title="Myanmar">Burma</a></td>
#  <td>30 November 1961</td>
#  <td>31 December 1971</td>
#  <td>First non-European to hold office
#  </td></tr>,
#  <tr>
#  <td>4</td>
#  <td><b><a href="/wiki/Kurt_Waldheim" title="Kurt Waldheim">Kurt Waldheim</a></b></td>
#  <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/41/Flag_of_Austria.svg/23px-Flag_of_Austria.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/41/Flag_of_Austria.svg/35px-Flag_of_Austria.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/41/Flag_of_Austria.svg/45px-Flag_of_Austria.svg.png 2x" width="23"/> </span><a href="/wiki/Austria" title="Austria">Austria</a></td>
#  <td>1 January 1972</td>
#  <td>31 December 1981</td>
#  <td>
#  </td></tr>,
#  <tr>
#  <td>5</td>
#  <td><b><a href="/wiki/Javier_P%C3%A9rez_de_Cu%C3%A9llar" title="Javier Pérez de Cuéllar">Javier Pérez de Cuéllar</a></b></td>
#  <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/c/cf/Flag_of_Peru.svg/23px-Flag_of_Peru.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/c/cf/Flag_of_Peru.svg/35px-Flag_of_Peru.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/c/cf/Flag_of_Peru.svg/45px-Flag_of_Peru.svg.png 2x" width="23"/> </span><a href="/wiki/Peru" title="Peru">Peru</a></td>
#  <td>1 January 1982</td>
#  <td>31 December 1991</td>
#  <td>
#  </td></tr>,
#  <tr>
#  <td>6</td>
#  <td><b><a href="/wiki/Boutros_Boutros-Ghali" title="Boutros Boutros-Ghali">Boutros Boutros-Ghali</a></b></td>
#  <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/fe/Flag_of_Egypt.svg/23px-Flag_of_Egypt.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/fe/Flag_of_Egypt.svg/35px-Flag_of_Egypt.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/fe/Flag_of_Egypt.svg/45px-Flag_of_Egypt.svg.png 2x" width="23"/> </span><a href="/wiki/Egypt" title="Egypt">Egypt</a></td>
#  <td>1 January 1992</td>
#  <td>31 December 1996</td>
#  <td>Served for the shortest time
#  </td></tr>,
#  <tr>
#  <td>7</td>
#  <td><b><a href="/wiki/Kofi_Annan" title="Kofi Annan">Kofi Annan</a></b></td>
#  <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/19/Flag_of_Ghana.svg/23px-Flag_of_Ghana.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/19/Flag_of_Ghana.svg/35px-Flag_of_Ghana.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/19/Flag_of_Ghana.svg/45px-Flag_of_Ghana.svg.png 2x" width="23"/> </span><a href="/wiki/Ghana" title="Ghana">Ghana</a></td>
#  <td>1 January 1997</td>
#  <td>31 December 2006</td>
#  <td>
#  </td></tr>,
#  <tr>
#  <td>8</td>
#  <td><b><a href="/wiki/Ban_Ki-moon" title="Ban Ki-moon">Ban Ki-moon</a></b></td>
#  <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/09/Flag_of_South_Korea.svg/23px-Flag_of_South_Korea.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/09/Flag_of_South_Korea.svg/35px-Flag_of_South_Korea.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/0/09/Flag_of_South_Korea.svg/45px-Flag_of_South_Korea.svg.png 2x" width="23"/> </span><a href="/wiki/South_Korea" title="South Korea">South Korea</a></td>
#  <td>1 January 2007</td>
#  <td>31 December 2016</td>
#  <td>
#  </td></tr>,
#  <tr>
#  <td>9</td>
#  <td><b><a href="/wiki/Ant%C3%B3nio_Guterres" title="António Guterres">António Guterres</a></b></td>
#  <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="400" data-file-width="600" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/5c/Flag_of_Portugal.svg/23px-Flag_of_Portugal.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/5c/Flag_of_Portugal.svg/35px-Flag_of_Portugal.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/5c/Flag_of_Portugal.svg/45px-Flag_of_Portugal.svg.png 2x" width="23"/> </span><a href="/wiki/Portugal" title="Portugal">Portugal</a></td>
#  <td>1 January 2017</td>
#  <td><i>Incumbent</i></td>
#  <td>
#  </td></tr>]

# %%
single_person = secretary_test[1]
single_person
# Out:
# <tr>
# <td>-
# </td>
# <td><b><a href="/wiki/Gladwyn_Jebb" title="Gladwyn Jebb">Gladwyn Jebb</a></b>
# </td>
# <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="1200" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/en/thumb/a/ae/Flag_of_the_United_Kingdom.svg/23px-Flag_of_the_United_Kingdom.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/a/ae/Flag_of_the_United_Kingdom.svg/35px-Flag_of_the_United_Kingdom.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/a/ae/Flag_of_the_United_Kingdom.svg/46px-Flag_of_the_United_Kingdom.svg.png 2x" width="23"/> </span><a href="/wiki/United_Kingdom" title="United Kingdom">United Kingdom</a>
# </td>
# <td>24 October 1945
# </td>
# <td>2 February 1946
# </td>
# <td>Served as <a href="/wiki/Acting_(law)" title="Acting (law)">Acting</a> Secretary-General until Lie's election
# </td></tr>

# %%
single_position = single_person.find_all("td")
single_position
# Out:
# [<td>-
#  </td>,
#  <td><b><a href="/wiki/Gladwyn_Jebb" title="Gladwyn Jebb">Gladwyn Jebb</a></b>
#  </td>,
#  <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="1200" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/en/thumb/a/ae/Flag_of_the_United_Kingdom.svg/23px-Flag_of_the_United_Kingdom.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/a/ae/Flag_of_the_United_Kingdom.svg/35px-Flag_of_the_United_Kingdom.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/a/ae/Flag_of_the_United_Kingdom.svg/46px-Flag_of_the_United_Kingdom.svg.png 2x" width="23"/> </span><a href="/wiki/United_Kingdom" title="United Kingdom">United Kingdom</a>
#  </td>,
#  <td>24 October 1945
#  </td>,
#  <td>2 February 1946
#  </td>,
#  <td>Served as <a href="/wiki/Acting_(law)" title="Acting (law)">Acting</a> Secretary-General until Lie's election
#  </td>]

# %%
actual_position = single_position[0]
actual_position
# Out:
# <td>-
# </td>

# %%
actual_position.contents[0]
# Out:
# '-\n'

# %%
sample_position = actual_position.contents[0]
sample_position = sample_position.strip()
sample_position
# Out:
# '-'

# %%
link_test = single_person.find("a")
link_test
# Out:
# <a href="/wiki/Gladwyn_Jebb" title="Gladwyn Jebb">Gladwyn Jebb</a>

# %%
sample_link = link_test.get('href')
sample_link
# Out:
# '/wiki/Gladwyn_Jebb'

# %%
full_link = "https://en.wikipedia.org/" + sample_link
full_link
# Out:
# 'https://en.wikipedia.org//wiki/Gladwyn_Jebb'

# %%
name = single_position[1]
sample_name = name.find('a')
sample_name = sample_name.contents[0]
sample_name
# Out:
# 'Gladwyn Jebb'

# %%
origin = single_position[2]
sample_origin = origin.find('a')
sample_origin = sample_origin.contents[0]
sample_origin
# Out:
# 'United Kingdom'

# %%
otherlink = single_position[2]
sample_otherlink = otherlink.find('a')
sample_otherlink = sample_otherlink.get('href')
fullother_link = "https://en.wikipedia.org/" + sample_otherlink
fullother_link
# Out:
# 'https://en.wikipedia.org//wiki/United_Kingdom'

# %%
took = single_position[3]
sample_took = took.contents[0]
sample_took = sample_took.strip()
sample_took
# Out:
# '24 October 1945'

# %%
left = single_position[4]
sample_left = left.contents[0]
sample_left = sample_left.strip()
sample_left
# Out:
# '2 February 1946'

# %%
notes = single_position[5]
sample_notes = notes.contents[0]
sample_notes
# Out:
# 'Served as '

# %%
del secretary_test[0]
secretary_test
# Out:
# [<tr>
#  <td>-
#  </td>
#  <td><b><a href="/wiki/Gladwyn_Jebb" title="Gladwyn Jebb">Gladwyn Jebb</a></b>
#  </td>
#  <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="1200" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/en/thumb/a/ae/Flag_of_the_United_Kingdom.svg/23px-Flag_of_the_United_Kingdom.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/a/ae/Flag_of_the_United_Kingdom.svg/35px-Flag_of_the_United_Kingdom.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/a/ae/Flag_of_the_United_Kingdom.svg/46px-Flag_of_the_United_Kingdom.svg.png 2x" width="23"/> </span><a href="/wiki/United_Kingdom" title="United Kingdom">United Kingdom</a>
#  </td>
#  <td>24 October 1945
#  </td>
#  <td>2 February 1946
#  </td>
#  <td>Served as <a href="/wiki/Acting_(law)" title="Acting (law)">Acting</a> Secretary-General until Lie's election
#  </td></tr>,
#  <tr>
#  <td>1</td>
#  <td><b><a href="/wiki/Trygve_Lie" title="Trygve Lie">Trygve Lie</a></b></td>
#  <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="372" data-file-width="512" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/d9/Flag_of_Norway.svg/21px-Flag_of_Norway.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/d9/Flag_of_Norway.svg/32px-Flag_of_Norway.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/d9/Flag_of_Norway.svg/41px-Flag_of_Norway.svg.png 2x" width="21"/> </span><a href="/wiki/Norway" title="Norway">Norway</a></td>
#  <td>2 February 1946</td>
#  <td>10 November 1952</td>
#  <td>Resigned
#  </td></tr>,
#  <tr>
#  <td>2</td>
#  <td><b><a href="/wiki/Dag_Hammarskj%C3%B6ld" title="Dag Hammarskjöld">Dag Hammarskjöld</a></b></td>
#  <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="1000" data-file-width="1600" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/en/thumb/4/4c/Flag_of_Sweden.svg/23px-Flag_of_Sweden.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/4/4c/Flag_of_Sweden.svg/35px-Flag_of_Sweden.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/4/4c/Flag_of_Sweden.svg/46px-Flag_of_Sweden.svg.png 2x" width="23"/> </span><a href="/wiki/Sweden" title="Sweden">Sweden</a></td>
#  <td>10 April 1953</td>
#  <td>18 September 1961</td>
#  <td>Died in office
#  </td></tr>,
#  <tr>
#  <td>3</td>
#  <td><b><a href="/wiki/U_Thant" title="U Thant">U Thant</a></b></td>
#  <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="500" data-file-width="900" decoding="async" height="13" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/51/Flag_of_Burma_%281948%E2%80%931974%29.svg/23px-Flag_of_Burma_%281948%E2%80%931974%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/51/Flag_of_Burma_%281948%E2%80%931974%29.svg/35px-Flag_of_Burma_%281948%E2%80%931974%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/51/Flag_of_Burma_%281948%E2%80%931974%29.svg/46px-Flag_of_Burma_%281948%E2%80%931974%29.svg.png 2x" width="23"/> </span><a href="/wiki/Myanmar" title="Myanmar">Burma</a></td>
#  <td>30 November 1961</td>
#  <td>31 December 1971</td>
#  <td>First non-European to hold office
#  </td></tr>,
#  <tr>
#  <td>4</td>
#  <td><b><a href="/wiki/Kurt_Waldheim" title="Kurt Waldheim">Kurt Waldheim</a></b></td>
#  <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/41/Flag_of_Austria.svg/23px-Flag_of_Austria.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/41/Flag_of_Austria.svg/35px-Flag_of_Austria.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/41/Flag_of_Austria.svg/45px-Flag_of_Austria.svg.png 2x" width="23"/> </span><a href="/wiki/Austria" title="Austria">Austria</a></td>
#  <td>1 January 1972</td>
#  <td>31 December 1981</td>
#  <td>
#  </td></tr>,
#  <tr>
#  <td>5</td>
#  <td><b><a href="/wiki/Javier_P%C3%A9rez_de_Cu%C3%A9llar" title="Javier Pérez de Cuéllar">Javier Pérez de Cuéllar</a></b></td>
#  <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/c/cf/Flag_of_Peru.svg/23px-Flag_of_Peru.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/c/cf/Flag_of_Peru.svg/35px-Flag_of_Peru.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/c/cf/Flag_of_Peru.svg/45px-Flag_of_Peru.svg.png 2x" width="23"/> </span><a href="/wiki/Peru" title="Peru">Peru</a></td>
#  <td>1 January 1982</td>
#  <td>31 December 1991</td>
#  <td>
#  </td></tr>,
#  <tr>
#  <td>6</td>
#  <td><b><a href="/wiki/Boutros_Boutros-Ghali" title="Boutros Boutros-Ghali">Boutros Boutros-Ghali</a></b></td>
#  <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/fe/Flag_of_Egypt.svg/23px-Flag_of_Egypt.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/fe/Flag_of_Egypt.svg/35px-Flag_of_Egypt.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/fe/Flag_of_Egypt.svg/45px-Flag_of_Egypt.svg.png 2x" width="23"/> </span><a href="/wiki/Egypt" title="Egypt">Egypt</a></td>
#  <td>1 January 1992</td>
#  <td>31 December 1996</td>
#  <td>Served for the shortest time
#  </td></tr>,
#  <tr>
#  <td>7</td>
#  <td><b><a href="/wiki/Kofi_Annan" title="Kofi Annan">Kofi Annan</a></b></td>
#  <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/19/Flag_of_Ghana.svg/23px-Flag_of_Ghana.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/19/Flag_of_Ghana.svg/35px-Flag_of_Ghana.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/19/Flag_of_Ghana.svg/45px-Flag_of_Ghana.svg.png 2x" width="23"/> </span><a href="/wiki/Ghana" title="Ghana">Ghana</a></td>
#  <td>1 January 1997</td>
#  <td>31 December 2006</td>
#  <td>
#  </td></tr>,
#  <tr>
#  <td>8</td>
#  <td><b><a href="/wiki/Ban_Ki-moon" title="Ban Ki-moon">Ban Ki-moon</a></b></td>
#  <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/09/Flag_of_South_Korea.svg/23px-Flag_of_South_Korea.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/09/Flag_of_South_Korea.svg/35px-Flag_of_South_Korea.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/0/09/Flag_of_South_Korea.svg/45px-Flag_of_South_Korea.svg.png 2x" width="23"/> </span><a href="/wiki/South_Korea" title="South Korea">South Korea</a></td>
#  <td>1 January 2007</td>
#  <td>31 December 2016</td>
#  <td>
#  </td></tr>,
#  <tr>
#  <td>9</td>
#  <td><b><a href="/wiki/Ant%C3%B3nio_Guterres" title="António Guterres">António Guterres</a></b></td>
#  <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="400" data-file-width="600" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/5c/Flag_of_Portugal.svg/23px-Flag_of_Portugal.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/5c/Flag_of_Portugal.svg/35px-Flag_of_Portugal.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/5c/Flag_of_Portugal.svg/45px-Flag_of_Portugal.svg.png 2x" width="23"/> </span><a href="/wiki/Portugal" title="Portugal">Portugal</a></td>
#  <td>1 January 2017</td>
#  <td><i>Incumbent</i></td>
#  <td>
#  </td></tr>]

# %%
test_list = []

for row in secretary_test:
    
    tags = []
    
    test = row.find_all("td")
    
    tags.append(test)
    
    for single_position in tags:
        
        try:
            actual_position = single_position[0]
            actual_position.contents[0]
            sample_position = actual_position.contents[0]
            sample_position = sample_position.strip()
             
            link_test = single_person.find("a")
            sample_link = link_test.get('href')
            full_link = "https://en.wikipedia.org/" + sample_link
            
            name = single_position[1]
            sample_name = name.find('a')
            sample_name = sample_name.contents[0]
             
            origin = single_position[2]
            sample_origin = origin.find('a')
            sample_origin = sample_origin.contents[0]
            
            otherlink = single_position[2]
            sample_otherlink = otherlink.find('a')
            sample_otherlink = sample_otherlink.get('href')
            fullother_link = "https://en.wikipedia.org/" + sample_otherlink
            
            took = single_position[3]
            sample_took = took.contents[0]
            sample_took = sample_took.strip() 
            
            left = single_position[4]
            sample_left = left.contents[0]
            sample_left = sample_left.strip()
            
            notes = single_position[5]
            sample_notes = notes.contents[0]
            sample_notes = sample_notes.strip()

            row_data = [sample_position, full_link, sample_name, sample_origin, fullother_link, sample_took, sample_left, sample_notes]

            test_list.append(row_data)
            
        except:
            continue
    
# show list
test_list
# Out:
# [['-',
#   'https://en.wikipedia.org//wiki/Gladwyn_Jebb',
#   'Gladwyn Jebb',
#   'United Kingdom',
#   'https://en.wikipedia.org//wiki/United_Kingdom',
#   '24 October 1945',
#   '2 February 1946',
#   'Served as'],
#  ['1',
#   'https://en.wikipedia.org//wiki/Gladwyn_Jebb',
#   'Trygve Lie',
#   'Norway',
#   'https://en.wikipedia.org//wiki/Norway',
#   '2 February 1946',
#   '10 November 1952',
#   'Resigned'],
#  ['2',
#   'https://en.wikipedia.org//wiki/Gladwyn_Jebb',
#   'Dag Hammarskjöld',
#   'Sweden',
#   'https://en.wikipedia.org//wiki/Sweden',
#   '10 April 1953',
#   '18 September 1961',
#   'Died in office'],
#  ['3',
#   'https://en.wikipedia.org//wiki/Gladwyn_Jebb',
#   'U Thant',
#   'Burma',
#   'https://en.wikipedia.org//wiki/Myanmar',
#   '30 November 1961',
#   '31 December 1971',
#   'First non-European to hold office'],
#  ['4',
#   'https://en.wikipedia.org//wiki/Gladwyn_Jebb',
#   'Kurt Waldheim',
#   'Austria',
#   'https://en.wikipedia.org//wiki/Austria',
#   '1 January 1972',
#   '31 December 1981',
#   ''],
#  ['5',
#   'https://en.wikipedia.org//wiki/Gladwyn_Jebb',
#   'Javier Pérez de Cuéllar',
#   'Peru',
#   'https://en.wikipedia.org//wiki/Peru',
#   '1 January 1982',
#   '31 December 1991',
#   ''],
#  ['6',
#   'https://en.wikipedia.org//wiki/Gladwyn_Jebb',
#   'Boutros Boutros-Ghali',
#   'Egypt',
#   'https://en.wikipedia.org//wiki/Egypt',
#   '1 January 1992',
#   '31 December 1996',
#   'Served for the shortest time'],
#  ['7',
#   'https://en.wikipedia.org//wiki/Gladwyn_Jebb',
#   'Kofi Annan',
#   'Ghana',
#   'https://en.wikipedia.org//wiki/Ghana',
#   '1 January 1997',
#   '31 December 2006',
#   ''],
#  ['8',
#   'https://en.wikipedia.org//wiki/Gladwyn_Jebb',
#   'Ban Ki-moon',
#   'South Korea',
#   'https://en.wikipedia.org//wiki/South_Korea',
#   '1 January 2007',
#   '31 December 2016',
#   '']]

# %%
f = csv.writer(open('secretary.csv', 'w'))

headers = ["position", "link", "name", "country_origin", "country_link", "took_office", "left_office", "notes"]

f.writerow(headers)

for row in test_list:
    f.writerow(row)

# %%
import pandas as pd

# create data frame 
df = pd.DataFrame(test_list, columns=headers)

# show df
df
# Out:
#   position                                         link  \
# 0        -  https://en.wikipedia.org//wiki/Gladwyn_Jebb
# 1        1  https://en.wikipedia.org//wiki/Gladwyn_Jebb
# 2        2  https://en.wikipedia.org//wiki/Gladwyn_Jebb
# 3        3  https://en.wikipedia.org//wiki/Gladwyn_Jebb
# 4        4  https://en.wikipedia.org//wiki/Gladwyn_Jebb
# 5        5  https://en.wikipedia.org//wiki/Gladwyn_Jebb
# 6        6  https://en.wikipedia.org//wiki/Gladwyn_Jebb
# 7        7  https://en.wikipedia.org//wiki/Gladwyn_Jebb
# 8        8  https://en.wikipedia.org//wiki/Gladwyn_Jebb
#
#                       name  country_origin  \
# 0             Gladwyn Jebb  United Kingdom
# 1               Trygve Lie          Norway
# 2         Dag Hammarskjöld          Sweden
# 3                  U Thant           Burma
# 4            Kurt Waldheim         Austria
# 5  Javier Pérez de Cuéllar            Peru
# 6    Boutros Boutros-Ghali           Egypt
# 7               Kofi Annan           Ghana
# 8              Ban Ki-moon     South Korea
#
#                                     country_link       took_office  \
# 0  https://en.wikipedia.org//wiki/United_Kingdom   24 October 1945
# 1          https://en.wikipedia.org//wiki/Norway   2 February 1946
# 2          https://en.wikipedia.org//wiki/Sweden     10 April 1953
# 3         https://en.wikipedia.org//wiki/Myanmar  30 November 1961
# 4         https://en.wikipedia.org//wiki/Austria    1 January 1972
# 5            https://en.wikipedia.org//wiki/Peru    1 January 1982
# 6           https://en.wikipedia.org//wiki/Egypt    1 January 1992
# 7           https://en.wikipedia.org//wiki/Ghana    1 January 1997
# 8     https://en.wikipedia.org//wiki/South_Korea    1 January 2007
#
#          left_office                              notes
# 0    2 February 1946                          Served as
# 1   10 November 1952                           Resigned
# 2  18 September 1961                     Died in office
# 3   31 December 1971  First non-European to hold office
# 4   31 December 1981
# 5   31 December 1991
# 6   31 December 1996       Served for the shortest time
# 7   31 December 2006
# 8   31 December 2016

# %% [markdown]
# **Q5: What challenges or roadblocks did you face working on Q4? What parts of the program do you understand/feel ready to develop at this point? What parts of the program are less clear?**

# %% [markdown]
# **Answer**: Some challenges I faced was to account for the first row having a value of - as it's number. I had to narrow down the position and then use sample_position = sample_position.strip() to strip the /n. One other roadblock was trying to find certain links such as with Gladwyn Jebb. I had to narrow down the link by using .get and finding the link using .find(). I then had to do the same thing with the link for the location but use different position. I feel ready to be able to use .contents and .find() but I was succesfully able to write extracted row contents to csv file.

# %%
# your codes here (if needed)

# %% [markdown]
# **Q6: Describe in your own words how the url generation program covered in the previous section of the lab works. The full program is also included below. What is happening in the different program components?**

# %%
root = "https://www.sports-reference.com/cfb/schools/notre-dame/"

years = range(1899, 2021, 1)

tag = "-schedule.html"

urls = []

for year in years:
    urls.append(root + str(year) + tag)
    
urls

# %% [markdown]
# **Answer**: If we have a list of urls and we have a program working on one page, you can iterate over the list of urls to scrape data over a series of wewb pages. Here we have two variables with root and tag that are assigned to string variables. the root has the beginning of the url while the tag has the end of the url. Range takes a list of years for the daes we want to cover. Later in the program is an empty list where we can use a forloop that concatenates the full url. we append to our empty list the root, the year (which is converted to a string) and then the tag. We then can on urls to show list.

# %%
# your codes here (if needed)

# %% [markdown]
# <strong>Q7: Select another Sports Reference web page that follows this pattern and write a program that generates a list of full URLs for that team/organization.
#
# A few places to start:
# - Baseball Reference season web pages have the following URL pattern:
#   * `https://www.baseball-reference.com/teams/`, `TEAM ABBREVIATION`, `SEASON`, `.shtml`
# - Basketball Reference season web pages have a similar pattern for NBA teams:
#   * `https://www.basketball-reference.com/teams/`, `TEAM ABBREVIATION`, `SEASON`, `.html`
# - Basketball Reference uses a slightly different pattern for its WNBA pages:
#   * `https://www.basketball-reference.com/wnba/teams`, `TEAM ABBREVIATION`, `SEASON`, `.html`
# - College Basketball Reference pages also follow a pattern:
#   * `https://www.sports-reference.com/cbb/schools`, `SCHOOL ABBREVIATION`, `SEASON`, `.html`
# - For Hockey Reference pages:
#   * `https://www.hockey-reference.com/teams/`, `TEAM ABBREVIATION`, `SEASON`, `.html`
# - Football Reference pages follow the same pattern for men's and women's teams:
#   * `https://fbref.com/en/squads/`, `SQUAD ID`, `SEASON`, `TEAM NAME`
# - Pro Football Reference pages also have a pattern:
#   * `https://www.pro-football-reference.com/teams/`, `TEAM ABBREVIATION`, `SEASON`, `.htm`
#
# NOTE: You DO NOT need to write a program that scrapes data from these pages for this question. The purpose of this question is to be able to programmatically generate a list of URLs that cover a date range.</strong>

# %% [markdown]
# **Answer**: Your answer here (double click to edit)

# %%
root = "https://www.baseball-reference.com/teams/DET/"

years = range(1899, 2021, 1)

tag = ".shtml"

urls = []

for year in years:
    urls.append(root + str(year) + tag)
    
urls
# Out:
# ['https://www.baseball-reference.com/teams/DET/1899.shtml',
#  'https://www.baseball-reference.com/teams/DET/1900.shtml',
#  'https://www.baseball-reference.com/teams/DET/1901.shtml',
#  'https://www.baseball-reference.com/teams/DET/1902.shtml',
#  'https://www.baseball-reference.com/teams/DET/1903.shtml',
#  'https://www.baseball-reference.com/teams/DET/1904.shtml',
#  'https://www.baseball-reference.com/teams/DET/1905.shtml',
#  'https://www.baseball-reference.com/teams/DET/1906.shtml',
#  'https://www.baseball-reference.com/teams/DET/1907.shtml',
#  'https://www.baseball-reference.com/teams/DET/1908.shtml',
#  'https://www.baseball-reference.com/teams/DET/1909.shtml',
#  'https://www.baseball-reference.com/teams/DET/1910.shtml',
#  'https://www.baseball-reference.com/teams/DET/1911.shtml',
#  'https://www.baseball-reference.com/teams/DET/1912.shtml',
#  'https://www.baseball-reference.com/teams/DET/1913.shtml',
#  'https://www.baseball-reference.com/teams/DET/1914.shtml',
#  'https://www.baseball-reference.com/teams/DET/1915.shtml',
#  'https://www.baseball-reference.com/teams/DET/1916.shtml',
#  'https://www.baseball-reference.com/teams/DET/1917.shtml',
#  'https://www.baseball-reference.com/teams/DET/1918.shtml',
#  'https://www.baseball-reference.com/teams/DET/1919.shtml',
#  'https://www.baseball-reference.com/teams/DET/1920.shtml',
#  'https://www.baseball-reference.com/teams/DET/1921.shtml',
#  'https://www.baseball-reference.com/teams/DET/1922.shtml',
#  'https://www.baseball-reference.com/teams/DET/1923.shtml',
#  'https://www.baseball-reference.com/teams/DET/1924.shtml',
#  'https://www.baseball-reference.com/teams/DET/1925.shtml',
#  'https://www.baseball-reference.com/teams/DET/1926.shtml',
#  'https://www.baseball-reference.com/teams/DET/1927.shtml',
#  'https://www.baseball-reference.com/teams/DET/1928.shtml',
#  'https://www.baseball-reference.com/teams/DET/1929.shtml',
#  'https://www.baseball-reference.com/teams/DET/1930.shtml',
#  'https://www.baseball-reference.com/teams/DET/1931.shtml',
#  'https://www.baseball-reference.com/teams/DET/1932.shtml',
#  'https://www.baseball-reference.com/teams/DET/1933.shtml',
#  'https://www.baseball-reference.com/teams/DET/1934.shtml',
#  'https://www.baseball-reference.com/teams/DET/1935.shtml',
#  'https://www.baseball-reference.com/teams/DET/1936.shtml',
#  'https://www.baseball-reference.com/teams/DET/1937.shtml',
#  'https://www.baseball-reference.com/teams/DET/1938.shtml',
#  'https://www.baseball-reference.com/teams/DET/1939.shtml',
#  'https://www.baseball-reference.com/teams/DET/1940.shtml',
#  'https://www.baseball-reference.com/teams/DET/1941.shtml',
#  'https://www.baseball-reference.com/teams/DET/1942.shtml',
#  'https://www.baseball-reference.com/teams/DET/1943.shtml',
#  'https://www.baseball-reference.com/teams/DET/1944.shtml',
#  'https://www.baseball-reference.com/teams/DET/1945.shtml',
#  'https://www.baseball-reference.com/teams/DET/1946.shtml',
#  'https://www.baseball-reference.com/teams/DET/1947.shtml',
#  'https://www.baseball-reference.com/teams/DET/1948.shtml',
#  'https://www.baseball-reference.com/teams/DET/1949.shtml',
#  'https://www.baseball-reference.com/teams/DET/1950.shtml',
#  'https://www.baseball-reference.com/teams/DET/1951.shtml',
#  'https://www.baseball-reference.com/teams/DET/1952.shtml',
#  'https://www.baseball-reference.com/teams/DET/1953.shtml',
#  'https://www.baseball-reference.com/teams/DET/1954.shtml',
#  'https://www.baseball-reference.com/teams/DET/1955.shtml',
#  'https://www.baseball-reference.com/teams/DET/1956.shtml',
#  'https://www.baseball-reference.com/teams/DET/1957.shtml',
#  'https://www.baseball-reference.com/teams/DET/1958.shtml',
#  'https://www.baseball-reference.com/teams/DET/1959.shtml',
#  'https://www.baseball-reference.com/teams/DET/1960.shtml',
#  'https://www.baseball-reference.com/teams/DET/1961.shtml',
#  'https://www.baseball-reference.com/teams/DET/1962.shtml',
#  'https://www.baseball-reference.com/teams/DET/1963.shtml',
#  'https://www.baseball-reference.com/teams/DET/1964.shtml',
#  'https://www.baseball-reference.com/teams/DET/1965.shtml',
#  'https://www.baseball-reference.com/teams/DET/1966.shtml',
#  'https://www.baseball-reference.com/teams/DET/1967.shtml',
#  'https://www.baseball-reference.com/teams/DET/1968.shtml',
#  'https://www.baseball-reference.com/teams/DET/1969.shtml',
#  'https://www.baseball-reference.com/teams/DET/1970.shtml',
#  'https://www.baseball-reference.com/teams/DET/1971.shtml',
#  'https://www.baseball-reference.com/teams/DET/1972.shtml',
#  'https://www.baseball-reference.com/teams/DET/1973.shtml',
#  'https://www.baseball-reference.com/teams/DET/1974.shtml',
#  'https://www.baseball-reference.com/teams/DET/1975.shtml',
#  'https://www.baseball-reference.com/teams/DET/1976.shtml',
#  'https://www.baseball-reference.com/teams/DET/1977.shtml',
#  'https://www.baseball-reference.com/teams/DET/1978.shtml',
#  'https://www.baseball-reference.com/teams/DET/1979.shtml',
#  'https://www.baseball-reference.com/teams/DET/1980.shtml',
#  'https://www.baseball-reference.com/teams/DET/1981.shtml',
#  'https://www.baseball-reference.com/teams/DET/1982.shtml',
#  'https://www.baseball-reference.com/teams/DET/1983.shtml',
#  'https://www.baseball-reference.com/teams/DET/1984.shtml',
#  'https://www.baseball-reference.com/teams/DET/1985.shtml',
#  'https://www.baseball-reference.com/teams/DET/1986.shtml',
#  'https://www.baseball-reference.com/teams/DET/1987.shtml',
#  'https://www.baseball-reference.com/teams/DET/1988.shtml',
#  'https://www.baseball-reference.com/teams/DET/1989.shtml',
#  'https://www.baseball-reference.com/teams/DET/1990.shtml',
#  'https://www.baseball-reference.com/teams/DET/1991.shtml',
#  'https://www.baseball-reference.com/teams/DET/1992.shtml',
#  'https://www.baseball-reference.com/teams/DET/1993.shtml',
#  'https://www.baseball-reference.com/teams/DET/1994.shtml',
#  'https://www.baseball-reference.com/teams/DET/1995.shtml',
#  'https://www.baseball-reference.com/teams/DET/1996.shtml',
#  'https://www.baseball-reference.com/teams/DET/1997.shtml',
#  'https://www.baseball-reference.com/teams/DET/1998.shtml',
#  'https://www.baseball-reference.com/teams/DET/1999.shtml',
#  'https://www.baseball-reference.com/teams/DET/2000.shtml',
#  'https://www.baseball-reference.com/teams/DET/2001.shtml',
#  'https://www.baseball-reference.com/teams/DET/2002.shtml',
#  'https://www.baseball-reference.com/teams/DET/2003.shtml',
#  'https://www.baseball-reference.com/teams/DET/2004.shtml',
#  'https://www.baseball-reference.com/teams/DET/2005.shtml',
#  'https://www.baseball-reference.com/teams/DET/2006.shtml',
#  'https://www.baseball-reference.com/teams/DET/2007.shtml',
#  'https://www.baseball-reference.com/teams/DET/2008.shtml',
#  'https://www.baseball-reference.com/teams/DET/2009.shtml',
#  'https://www.baseball-reference.com/teams/DET/2010.shtml',
#  'https://www.baseball-reference.com/teams/DET/2011.shtml',
#  'https://www.baseball-reference.com/teams/DET/2012.shtml',
#  'https://www.baseball-reference.com/teams/DET/2013.shtml',
#  'https://www.baseball-reference.com/teams/DET/2014.shtml',
#  'https://www.baseball-reference.com/teams/DET/2015.shtml',
#  'https://www.baseball-reference.com/teams/DET/2016.shtml',
#  'https://www.baseball-reference.com/teams/DET/2017.shtml',
#  'https://www.baseball-reference.com/teams/DET/2018.shtml',
#  'https://www.baseball-reference.com/teams/DET/2019.shtml',
#  'https://www.baseball-reference.com/teams/DET/2020.shtml']

# %% [markdown]
# **Q8: Describe the general approach to loading a web page in Python using `pd.read_html()`. What are the basic steps involved in this workflow, thinking about what happens to identify/isolate the specific table you want to work with?**

# %% [markdown]
# **Answer**: pd.read_html() can look for any <table> tag on a web page and reads each <table> tag's HTML into Python as a list of DataFrame objects. So in this example we are importing pandas, then storing the url as a variable, and passing the variable to pd.read_html which can read the table tags into Python as a list of DataFrames. You can then use index values to pull out each dataframe/

# %%
import pandas as pd

url = "https://www.baseball-reference.com/teams/DET/2021.shtml"

dfs = pd.read_html(url)

dfs

len(dfs)

# %% [markdown]
# <strong>Q9: For Q7, you generated a list of Sports Reference URLs covering a time span for a specific team/organization. Select three years and web pages from that list- something early in the time period covered, something in the middle of the time period covered, and something toward the end of the time period covered.
#
# Do these pages have the same pattern in terms of number and order of tables?
#
# For one of these pages, what table or tables on these pages would you want to be able to extract and work with?</strong>

# %% [markdown]
# **Answer**: So I chose three years from the list of detroit lions. These pages have the same pattern in terms of number and order of tables. They all have two data tables and are in the same order as illustrated by the headings on the tables when I isolate dfs[0] and dfs[1]. I want to extract work from the 2019 table

# %%
import pandas as pd

url = "https://www.baseball-reference.com/teams/DET/1903.shtml"

dfs = pd.read_html(url)

len(dfs)
# Out:
# 2

# %%
import pandas as pd

url = "https://www.baseball-reference.com/teams/DET/1952.shtml"

dfs = pd.read_html(url)

dfs

len(dfs)
# Out:
# 2

# %%
import pandas as pd

url = "https://www.baseball-reference.com/teams/DET/2019.shtml"

dfs = pd.read_html(url)

dfs

len(dfs)
# Out:
# 2

# %% [markdown]
# <strong>Q10: Develop an outline for a Python program that uses `pd.read_html()` to scrape data from one of the web pages you select in Q9.
#
# A preliminary workflow:
# - Use `pd.read_html()` to create a list of DataFrame objects
# - Identify which DataFrame object in the list is the table you want to work with
# - Isolate the list element to create a new DataFrame
# - Write the new DataFrame to a CSV file
#
# NOTE: For Q4, you did not need to have working code for all components of this program. Since `pd.read_html()` has an easier learning curve, let's see if we can flesh out more of this program. But if you run into problems, it's okay to focus on the conceptual framework for the web scraping program. Start to build out code where you can, but think about the programming version of outlining a paper.
#
# ANOTHER NOTE: For many Sports Reference pages, tables further down the page are buried in HTML comments. These tables will not show up when you use `pd.read_html()`. We can come back to these "hidden tables" in the final project, but for now, focus on the tables that do show up when you use `pd.read_html()`.</strong>

# %% [markdown]
# **Answer**: I first imported pandas and then assigned url variable to my 2019 statistics. I then used pd.read_html() to create a list of Data Frame objects and identified which object I wanted to use. After that I isolated it and wrote the new DataFrame to a CSV file.

# %%
import pandas as pd

url = "https://www.baseball-reference.com/teams/DET/2019.shtml"

dfs = pd.read_html(url)

len(dfs)
# Out:
# 2

# %%
players_df = dfs[1]

players_df
# Out:
#      Rk  Pos                 Name   Age   W    L   W-L%    ERA    G   GS  ...  \
# 0     1   SP        Matthew Boyd*    28   9   12   .429   4.56   32   32  ...
# 1     2   SP     Spencer Turnbull    26   3   17   .150   4.61   30   30  ...
# 2     3   SP       Daniel Norris*    26   3   13   .188   4.49   32   29  ...
# 3     4   SP    Jordan Zimmermann    33   1   13   .071   6.91   23   23  ...
# 4    Rk  Pos                 Name   Age   W    L   W-L%    ERA    G   GS  ...
# 5     5   CL         Shane Greene    30   0    2   .000   1.18   38    0  ...
# 6     6   RP        Nick Ramirez*    29   5    4   .556   4.07   46    0  ...
# 7     7   RP          Buck Farmer    28   6    6   .500   3.72   73    1  ...
# 8     8   RP          Joe Jimenez    24   4    7   .364   4.37   66    0  ...
# 9     9   RP       Daniel Stumpf*    28   1    1   .500   4.34   48    0  ...
# 10   Rk  Pos                 Name   Age   W    L   W-L%    ERA    G   GS  ...
# 11   10  NaN        Drew VerHagen    28   4    3   .571   5.90   22    4  ...
# 12   11  NaN        Gregory Soto*    24   0    5   .000   5.77   33    7  ...
# 13   12  NaN     Tyler Alexander*    24   1    4   .200   4.86   13    8  ...
# 14   13  NaN        Blaine Hardy*    32   1    1   .500   4.47   39    0  ...
# 15   14  NaN     Victor Alcantara    26   3    2   .600   4.85   46    0  ...
# 16   15  NaN      Ryan Carpenter*    28   1    6   .143   9.30    9    9  ...
# 17   16  NaN        Edwin Jackson    35   2    5   .286   8.47   10    8  ...
# 18   17  NaN         Jose Cisnero    30   0    4   .000   4.33   35    0  ...
# 19   18  NaN           Tyson Ross    32   1    5   .167   6.11    7    7  ...
# 20   19  NaN        Zac Reininger    26   0    3   .000   8.68   25    1  ...
# 21   20  NaN           Matt Hall*    25   0    1   .000   7.71   16    0  ...
# 22   21  NaN          David McKay    24   0    0    NaN   5.59   18    0  ...
# 23   22  NaN         Reed Garrett    26   0    0    NaN   8.22   13    0  ...
# 24   23  NaN         Austin Adams    32   0    0    NaN   5.14   13    0  ...
# 25   24  NaN       John Schreiber    25   2    0  1.000   6.23   13    0  ...
# 26   25  NaN      Eduardo Jimenez    24   0    0    NaN   5.91    8    0  ...
# 27   26  NaN          Matt Moore*    30   0    0    NaN   0.00    2    2  ...
# 28   27  NaN     Trevor Rosenthal    29   0    0    NaN   7.00   10    0  ...
# 29   28  NaN         Bryan Garcia    24   0    0    NaN  12.15    7    0  ...
# 30   29  NaN        Carlos Torres    36   0    0    NaN   7.50    4    0  ...
# 31   30  NaN      Jose Fernandez*    26   0    0    NaN  17.18    4    0  ...
# 32   31  NaN        Brandon Dixon    27   0    0    NaN   9.00    2    0  ...
# 33   32  NaN           Sandy Baez    25   0    0    NaN   9.00    1    0  ...
# 34  NaN  NaN          Team Totals  27.9  47  114   .292   5.24  161  161  ...
# 35  NaN  NaN  Rank in 15 AL teams   NaN  15    1    NaN     14  NaN  NaN  ...
# 36   Rk  Pos                 Name   Age   W    L   W-L%    ERA    G   GS  ...
#
#      WP    BF  ERA+    FIP   WHIP    H9  HR9   BB9   SO9  SO/W
# 0     6   788   104   4.32  1.230   8.6  1.9   2.4  11.6  4.76
# 1     9   656   103   3.99  1.436   9.3  0.8   3.6   8.9  2.47
# 2     5   610   106   4.61  1.330   9.6  1.6   2.4   7.8  3.29
# 3     3   504    69   4.79  1.518  11.7  1.5   2.0   6.6  3.28
# 4    WP    BF  ERA+    FIP   WHIP    H9  HR9   BB9   SO9  SO/W
# 5     0   151   405   3.69  0.868   5.0  1.2   2.8  10.2  3.58
# 6     6   348   117   4.51  1.393   8.6  1.2   4.0   8.4  2.11
# 7     4   288   128   3.88  1.271   8.2  1.1   3.2   9.7  3.04
# 8     1   257   109   4.66  1.324   8.4  2.0   3.5  12.4  3.57
# 9     0   135   111   5.08  1.724  10.9  1.6   4.7   8.7  1.87
# 10   WP    BF  ERA+    FIP   WHIP    H9  HR9   BB9   SO9  SO/W
# 11    3   258    81   4.87  1.603  10.9  1.4   3.6   7.9  2.22
# 12    5   276    83   5.40  1.855  11.5  1.4   5.2   7.0  1.36
# 13    1   235    98   4.15  1.398  11.4  1.5   1.2   7.9  6.71
# 14    3   182   107   5.72  1.150   7.7  2.0   2.6   5.9  2.23
# 15    3   182    99   5.72  1.406   9.5  1.7   3.2   5.1  1.60
# 16    0   197    52   6.93  1.820  13.5  2.7   2.9   5.5  1.92
# 17    3   192    57   6.70  1.907  12.8  2.5   4.3   7.6  1.74
# 18    1   162   111   4.66  1.528   8.9  1.3   4.8  10.2  2.11
# 19    1   162    78   5.99  1.670  10.4  1.8   4.6   6.4  1.39
# 20    1   140    55   8.82  2.143  14.1  3.5   5.1   5.5  1.06
# 21    1   113    62   5.19  1.843  10.8  1.5   5.8  10.4  1.80
# 22    2    81    87   3.11  1.241   7.0  0.9   4.2  13.5  3.22
# 23    0    77    59   7.19  2.413  14.1  1.8   7.6   5.9  0.77
# 24    0    65    95   5.93  1.714   9.0  1.3   6.4   5.8  0.90
# 25    1    59    78   4.44  1.538  11.1  2.1   2.8  13.2  4.75
# 26    1    49    83   4.34  1.594  10.1  0.8   4.2   6.8  1.60
# 27    0    33   NaN   1.71  0.400   2.7  0.0   0.9   8.1  9.00
# 28    4    42    70   4.55  1.556   3.0  0.0  11.0  12.0  1.09
# 29    1    33    41   5.31  2.100  12.2  1.4   6.8   9.5  1.40
# 30    1    29    67   5.88  1.667  13.5  3.0   1.5  12.0  8.00
# 31    0    23    30  10.58  3.000  14.7  2.5  12.3   4.9  0.40
# 32    0     9    61  11.71  0.500   4.5  4.5   0.0   4.5   NaN
# 33    0     5    70   3.21  2.000  18.0  0.0   0.0   0.0   NaN
# 34   66  6341    91   4.84  1.459   9.8  1.6   3.4   8.6  2.55
# 35  NaN   NaN   NaN    NaN    NaN   NaN  NaN   NaN   NaN   NaN
# 36   WP    BF  ERA+    FIP   WHIP    H9  HR9   BB9   SO9  SO/W
#
# [37 rows x 34 columns]

# %%
players_df.to_csv("sample_DET_players.csv", index=False)

# %% [markdown]
# **Q11: What challenges or roadblocks did you face working on Q10? What parts of the program do you understand and/or were able to develop? What parts of the program are less clear?**

# %% [markdown]
# **Answer**: I was succesfully able to develop the program and understood how to isolate my DataFrame. I was able to choose the index of my Data frame and assign it to a variable. I think the index part for the CSV was a little less clear but the program was still able to function and write to a CSV file.

# %%
# your codes here (if needed)

# %% [markdown]
# **Q12: Describe in your own words how program for scraping unstructured text covered in the previous section of the lab works. The full program is also included below. What is happening in the different program components?**

# %%
page = requests.get("https://ndsmcobserver.com/2021/10/south-bend-community-leaders-discuss-role-of-notre-dame-in-fight-for-black-civil-rights/")

soup = BeautifulSoup(page.text, 'html.parser')

article = soup.find_all(class_ = "content-body")

article_text = article[0]

article_paragraphs = article_text.find_all("p")

f = open("observer_text.txt", "a")

for paragraph in article_paragraphs:
    text = str(paragraph.contents[0])
    f.write(text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-cad2fe3c5316> in <module>
# ----> 1 page = requests.get("https://ndsmcobserver.com/2021/10/south-bend-community-leaders-discuss-role-of-notre-dame-in-fight-for-black-civil-rights/")
#       2
#       3 soup = BeautifulSoup(page.text, 'html.parser')
#       4
#       5 article = soup.find_all(class_ = "content-body")
#
# NameError: name 'requests' is not defined

# %% [markdown]
# **Answer**: First we are using requests.get to load the url. Then we still parse it as html to interact with it and make it into a beautifulsoup object. We need to find what is around paragraph tags to isolate parto of the html. So we look for class "content-body". We then refine it further by getting the content of the text with article [0]. Then we create a list like object by isolating paragraph tags. Later we create new txt file and open it in append mode. Finally we have a forloop that iterates and removes HTML markup for each paragraph.

# %%
# your codes here (if needed)

# %% [markdown]
# <strong>Q13: Select another web page that includes unstructured text. From looking at the public web page, what text do you want to scrape from this web page (i.e. specific sections, multiple paragraphs, etc.)?
#
# A few places to start for unstructured text:
# - [The Observer!](https://ndsmcobserver.com) (or another news publication of your choosing)
# - [WikiSource](https://en.wikisource.org/wiki/Main_Page)(a library of texts that are not covered by copyright)
#   * [U.S. Presidential State of the Union Addresses](https://en.wikisource.org/wiki/Portal:State_of_the_Union_Speeches_by_United_States_Presidents)
#   * [U.S. Presidential Inaugural Speeches](https://en.wikisource.org/wiki/Portal:Inaugural_Speeches_by_United_States_Presidents)
# - [Project Gutenberg](https://www.gutenberg.org) (a library of literary works or texts that are not covered by copyright)</strong>

# %% [markdown]
# **Answer**: The text I chose is titled "Building our sanctuary, one student at a time" from The Observer. I want to scrape multiple paragraphs from the article.

# %%
# your codes here (if needed)

# %% [markdown]
# **Q14: Take a look at the HTML for this page. What tags or other HTML components do you see around the section of the page you want to work with? For this question, we're thinking about how we will end up writing a program with `BeautifulSoup` to isolate a section of the web page.**

# %% [markdown]
# **Answer**: Looking at the HTML, i see <p> tags. Around that is <div class="content-body">. This has content body class that is shown once so I will utilize that to scrape.

# %%
# your codes here (if needed)

# %% [markdown]
# <strong>Q15: Develop an outline for a Python program that scrapes unstructured text from the web page you selected.
#
# A preliminary workflow:
# - Load URL and create BeautifulSoup object
# - Isolate section of HTML with your text (either directly or extract from list)
# - IF NEEDED: Isolate text elements (create list where each element is a section of text)
# - IF NEEDED: Extract text contents (isolate text from each section/paragraph)
# - Write text to TXT file
#
# NOTE: You do not need to have working code for all components of this program. That's where we're heading with the final project. At this point, we're focusing on the conceptual framework for the web scraping program. Start to build out code where you can, but think about the programming version of outlining a paper.</strong>

# %% [markdown]
# **Answer**: Your answer here (double click to edit)

# %%
import requests
from bs4 import BeautifulSoup

page = requests.get("https://ndsmcobserver.com/2021/11/building-our-sanctuary-one-student-at-a-time/")

soup = BeautifulSoup(page.text, 'html.parser')

observer = soup.find_all(class_ = "content-body")

observer_text = observer[0]

text_list = []

for paragraph in observer_paragraphs:
    paragraph = str(paragraph.contents[0])
    text_list.append(paragraph)
    
f = open("observer_text.txt", "a")

for paragraph in observer_paragraphs:
    text = str(paragraph.contents[0])
    f.write(text)

# %% [markdown]
# **Q16: What challenges or roadblocks did you face working on Q15? What parts of the program do you understand/feel ready to develop at this point? What parts of the program are less clear?**

# %% [markdown]
# **Answer**: I forgot to import requests and BeautifulSoup at the beginning as well as specify the content-body class. However, I was able narrow down my paragraphs and create a forloop that writes text to a txt file.

# %%
# your codes here (if needed)

# %% [markdown]
# # Final Project

# %% [markdown]
# For this project, I decided to examine a Smithsonian data file (https://photocontest.smithsonianmag.com/photocontest/archive/2020/where). In this case, I would be working with a type of unstructured data. It consists of a grid like structure of images with brief information underneath that is not structured in a chart format like Wikipedia. I wanted to partiuclarly scrape the first three categories from the finalists off of the site. These categories would be Natural World, People and Travel. My plan was to write the data into seperate CSV files for each seperate category. The challenges that I thought I would encounter would be organizing images or how to structure all the information in a chart. The initial plan would be using a for loop that would take each section using the same class name and iterating through my data. One challenge I encountered was with scraping the hashtags for an individual grid. I knew this would be a problem since each image has a different amount of hashtags. Therefore, after many trial and error I consulted w3schools and figured I could use a for loop that could append each tag together and use the join() method that takes all the hashtags and joins them into one string. This successfully worked and could account for all the different amount of hashtags. Furthermore, another challenge I encountered was with the for loop that would create a list of all my seperate grids and compile it. For this, I had to be careful with my variable names and make sure I was calling out grids which accounts for my entire grid structure for Natural World. After that I worked on how I can incorporate my previous code to web scrape the other categories. This was challenging as well as I had to be very specific with variable names and locate the right variables that were specific for the categories of "people" and "travel". I think the project helped my understanding of the importance of variables as well as how to expand on previous code. Once I had the code figured out for Natural World, I could apply it to different scenarios such as web scraping other categories such as People and Travel. Every line of code you create requires maintenance and small changes can require a lot of work. However, the final project was very useful in understanding the process of writing extensive code.

# %%
#First I imported libraries
import requests
from bs4 import BeautifulSoup
import csv
import pandas as pd

# %%
#Here I got the smithsonian magazine page with the url
page = requests.get('https://photocontest.smithsonianmag.com/photocontest/archive/2020/')
#Created a BeautifulSoup object
soup = BeautifulSoup(page.text, 'html.parser')

# %%
#Isolating the HTML with winners-category class
group = soup.find_all(class_ = 'winners-category')

# %%
#showing group of Finalists for Natural World
group[0]
# Out:
# <section class="winners-category">
# <h2>Finalists</h2>
# <h3>NATURAL WORLD</h3>
# <div class="photo-grid-photos" id="photoGridPhotos">
# <div class="photo-container" id="photoContainer1">
# <div class="grid-photo">
# <a class="lightbox-thumbnail" href="/photocontest/detail/crabeater-seals/">
# <img alt="Crabeater Seals thumbnail" src="https://th-thumbnailer.cdn-si-edu.com/el_0tAXud0t3EpTjl2j_c5FYHFo=/fit-in/600x0/filters:focal(2732x1817:2733x1818)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/c130aa79-3045-4d87-9287-ebb3c8c322c3.jpg"/>
# <div class="photographer">Florian Ledoux</div>
# <div class="photo-title">Crabeater Seals</div>
# </a>
# <div class="photo-tags">
# <div class="photo-tags">
# <a href="/photocontest/tags/antarctica/">#antarctica</a>
# <a href="/photocontest/tags/ice/">#ice</a>
# <a href="/photocontest/tags/nature/">#nature</a>
# <a href="/photocontest/tags/seal/">#seal</a>
# <a href="/photocontest/tags/wildlife/">#wildlife</a>
# </div>
# </div>
# </div>
# <div class="grid-photo">
# <a class="lightbox-thumbnail" href="/photocontest/detail/turtle-19/">
# <img alt="Turtle thumbnail" src="https://th-thumbnailer.cdn-si-edu.com/pFvOhv9r6ieQjCrixRLQUQ5ctmo=/fit-in/600x0/filters:focal(1000x750:1001x751)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/ded5bc33-a7ab-4558-b33a-a978b2eb4273.jpg"/>
# <div class="photographer">Galice Hoarau</div>
# <div class="photo-title">Turtle</div>
# </a>
# <div class="photo-tags">
# <div class="photo-tags">
# <a href="/photocontest/tags/indonesia/">#indonesia</a>
# <a href="/photocontest/tags/reef/">#reef</a>
# <a href="/photocontest/tags/turtle/">#turtle</a>
# </div>
# </div>
# </div>
# <div class="grid-photo">
# <a class="lightbox-thumbnail" href="/photocontest/detail/walrus-with-baby/">
# <img alt="Walrus With Baby thumbnail" src="https://th-thumbnailer.cdn-si-edu.com/BFarV8TaHBkTDTQAvPJCwZVw1EI=/fit-in/600x0/filters:focal(1700x1054:1701x1055)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/04437246-243e-459e-bcde-fea5d39b8b70.jpg"/>
# <div class="photographer">Gueorgui Petkov</div>
# <div class="photo-title">Walrus With Baby</div>
# </a>
# <div class="photo-tags">
# <div class="photo-tags">
# <a href="/photocontest/tags/arctic/">#arctic</a>
# <a href="/photocontest/tags/wildlife/">#wildlife</a>
# </div>
# </div>
# </div>
# <div class="grid-photo">
# <a class="lightbox-thumbnail" href="/photocontest/detail/goodbye-family/">
# <img alt="Goodbye Family thumbnail" src="https://th-thumbnailer.cdn-si-edu.com/yk4spV5F7hW_S6lUsKCxcDH7RMs=/fit-in/600x0/filters:focal(1500x975:1501x976)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/539bf07e-7be9-41b6-8e91-95d91c08cf8b.jpg"/>
# <div class="photographer">Vladimir Karamazov</div>
# <div class="photo-title">Goodbye Family</div>
# </a>
# <div class="photo-tags">
# <div class="photo-tags">
# <a href="/photocontest/tags/bulgaria/">#bulgaria</a>
# <a href="/photocontest/tags/snail/">#snail</a>
# </div>
# </div>
# </div>
# <div class="grid-photo">
# <a class="lightbox-thumbnail" href="/photocontest/detail/whale-tail-6/">
# <img alt="Whale Tail thumbnail" src="https://th-thumbnailer.cdn-si-edu.com/FD8Dhg1H2Ju5nfSp2gU-TrJa-0U=/fit-in/600x0/filters:focal(2661x712:2662x713)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/5a0c3c0f-1851-4e30-b258-c8b02faaa7b9.jpg"/>
# <div class="photographer">John Comisky</div>
# <div class="photo-title">Whale Tail</div>
# </a>
# <div class="photo-tags">
# <div class="photo-tags">
# <a href="/photocontest/tags/antarctica/">#antarctica</a>
# </div>
# </div>
# </div>
# <div class="grid-photo">
# <a class="lightbox-thumbnail" href="/photocontest/detail/unsung-warrior/">
# <img alt="Unsung Warrior thumbnail" src="https://th-thumbnailer.cdn-si-edu.com/yQmiLoUEZNa4NyR4lISYHkUgeC0=/fit-in/600x0/filters:focal(2736x1819:2737x1820)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/d07245cc-6d8e-418f-979a-170d104d05c9.jpg"/>
# <div class="photographer">Chandrashekhar Shirur</div>
# <div class="photo-title">Unsung Warrior</div>
# </a>
# <div class="photo-tags">
# <div class="photo-tags">
# <a href="/photocontest/tags/india/">#india</a>
# <a href="/photocontest/tags/reptile/">#reptile</a>
# <a href="/photocontest/tags/wildlife/">#wildlife</a>
# </div>
# </div>
# </div>
# <div class="grid-photo">
# <a class="lightbox-thumbnail" href="/photocontest/detail/robber-fly-with-dew/">
# <img alt="Robber Fly With Dew thumbnail" src="https://th-thumbnailer.cdn-si-edu.com/GXYzus6IAHK_aBa940pXjY0RLzM=/fit-in/600x0/filters:focal(1551x2326:1552x2327)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/11c798f3-8491-4f23-9e49-be049fcfe174.jpg"/>
# <div class="photographer">Frank Klein</div>
# <div class="photo-title">Robber Fly With Dew</div>
# </a>
# <div class="photo-tags">
# <div class="photo-tags">
# <a href="/photocontest/tags/texas/">#texas</a>
# </div>
# </div>
# </div>
# <div class="grid-photo">
# <a class="lightbox-thumbnail" href="/photocontest/detail/light-and-rain-1/">
# <img alt="Light and Rain thumbnail" src="https://th-thumbnailer.cdn-si-edu.com/x4iUB1YETPiSzchfptYgQFi8l8I=/fit-in/600x0/filters:focal(1800x1350:1801x1351)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/75ccc8f8-09b2-475d-803f-42d0ca48757f.jpg"/>
# <div class="photographer">Andro Loria</div>
# <div class="photo-title">Light and Rain</div>
# </a>
# <div class="photo-tags">
# <div class="photo-tags">
# <a href="/photocontest/tags/highlands/">#highlands</a>
# <a href="/photocontest/tags/iceland/">#iceland</a>
# <a href="/photocontest/tags/landscape/">#landscape</a>
# <a href="/photocontest/tags/weather/">#weather</a>
# </div>
# </div>
# </div>
# <div class="grid-photo">
# <a class="lightbox-thumbnail" href="/photocontest/detail/noble-1/">
# <img alt="At the Helm thumbnail" src="https://th-thumbnailer.cdn-si-edu.com/qGEPde6vf3ZA-qpkzSe7ud1lmH4=/fit-in/600x0/filters:focal(1000x905:1001x906)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/77c57a42-e64a-4e38-a2ae-8c1086065042.jpg"/>
# <div class="photographer">Ly Dang</div>
# <div class="photo-title">At the Helm</div>
# </a>
# <div class="photo-tags">
# <div class="photo-tags">
# <a href="/photocontest/tags/animal/">#animal</a>
# <a href="/photocontest/tags/baboon/">#baboon</a>
# <a href="/photocontest/tags/ethiopia/">#ethiopia</a>
# <a href="/photocontest/tags/monkey/">#monkey</a>
# <a href="/photocontest/tags/wildlife/">#wildlife</a>
# </div>
# </div>
# </div>
# <div class="grid-photo"><div class="grid-ad"><div><div class="photo-contest-grid-ad ad-slot photo-contest-grid-ad" data-ad-settings="defaultPhotoContestStream" id="div-gpt-ad-chuckweasley-photocontest-stream-1"></div></div></div></div>
# <div class="grid-photo">
# <a class="lightbox-thumbnail" href="/photocontest/detail/the-giraffe-and-the-roller/">
# <img alt="The Giraffe and the Roller thumbnail" src="https://th-thumbnailer.cdn-si-edu.com/G65wHhF668ZivXtQfpk3g-1tYOs=/fit-in/600x0/filters:focal(1000x800:1001x801)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/24d46b67-7858-473b-ab31-d66c429975f2.jpg"/>
# <div class="photographer">Yaron Schmid</div>
# <div class="photo-title">The Giraffe and the Roller</div>
# </a>
# <div class="photo-tags">
# <div class="photo-tags">
# <a href="/photocontest/tags/bird/">#bird</a>
# <a href="/photocontest/tags/giraffe/">#giraffe</a>
# <a href="/photocontest/tags/kenya/">#kenya</a>
# <a href="/photocontest/tags/nature/">#nature</a>
# <a href="/photocontest/tags/safari/">#safari</a>
# <a href="/photocontest/tags/wildlife/">#wildlife</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>

# %%
#Isolating group of Finalists for Natural World
natural_world = group[0]

# %%
#finding the individual grid (specifically Florian Ledoux)
grids = natural_world.find_all(class_ ="grid-photo")

first_grid = grids[0]
# Out:
# <section class="winners-category">
# <h3>PEOPLE</h3>
# <div class="photo-grid-photos" id="photoGridPhotos">
# <div class="photo-container" id="photoContainer1">
# <div class="grid-photo">
# <a class="lightbox-thumbnail" href="/photocontest/detail/proud-7/">
# <img alt="Nilima's Challenge thumbnail" src="https://th-thumbnailer.cdn-si-edu.com/HA-WGl4U_s6qrJwGEpgHQ3jSjs4=/fit-in/600x0/filters:focal(750x1001:751x1002)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/9f4a977a-cc98-455c-90bb-79e69d85640c.jpg"/>
# <div class="photographer">Mauro De Bettio</div>
# <div class="photo-title">Nilima's Challenge</div>
# </a>
# <div class="photo-tags">
# <div class="photo-tags">
# <a href="/photocontest/tags/bangladesh/">#bangladesh</a>
# </div>
# </div>
# </div>
# <div class="grid-photo">
# <a class="lightbox-thumbnail" href="/photocontest/detail/once-with-the-earth/">
# <img alt="Once With the Earth thumbnail" src="https://th-thumbnailer.cdn-si-edu.com/ETSl48rPSIqy8AG9-CyJhy-1RJk=/fit-in/600x0/filters:focal(750x1001:751x1002)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/b96e86ac-5110-4b11-abc5-db6e7cdc4d4d.jpg"/>
# <div class="photographer">Mauro De Bettio</div>
# <div class="photo-title">Once With the Earth</div>
# </a>
# <div class="photo-tags">
# <div class="photo-tags">
# <a href="/photocontest/tags/ethiopia/">#ethiopia</a>
# </div>
# </div>
# </div>
# <div class="grid-photo">
# <a class="lightbox-thumbnail" href="/photocontest/detail/at-the-brink-of-desperation-a-covid-19-story-from-bergamo/">
# <img alt="At the Brink of Desperation thumbnail" src="https://th-thumbnailer.cdn-si-edu.com/RdPs5ezbJjjmbZHYd1lRcjconLQ=/fit-in/600x0/filters:focal(1500x998:1501x999)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/22e2dc83-1c20-40c6-8c57-5693514f1d21.jpg"/>
# <div class="photographer">Mauro Scattolini</div>
# <div class="photo-title">At the Brink of Desperation</div>
# </a>
# <div class="photo-tags">
# <div class="photo-tags">
# <a href="/photocontest/tags/italy/">#italy</a>
# <a href="/photocontest/tags/people/">#people</a>
# </div>
# </div>
# </div>
# <div class="grid-photo">
# <a class="lightbox-thumbnail" href="/photocontest/detail/alms-1/">
# <img alt="Alms thumbnail" src="https://th-thumbnailer.cdn-si-edu.com/aN1NXXxK_t58yrvfVvROqFAYxyw=/fit-in/600x0/filters:focal(1000x665:1001x666)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/2f15d914-516b-4f39-bb39-9087a025719c.jpg"/>
# <div class="photographer">Sarah Wouters</div>
# <div class="photo-title">Alms</div>
# </a>
# <div class="photo-tags">
# <div class="photo-tags">
# <a href="/photocontest/tags/culture/">#culture</a>
# <a href="/photocontest/tags/thailand/">#thailand</a>
# </div>
# </div>
# </div>
# <div class="grid-photo">
# <a class="lightbox-thumbnail" href="/photocontest/detail/grandma-divers-10/">
# <img alt="Grandma Diver thumbnail" src="https://th-thumbnailer.cdn-si-edu.com/I5PwvaXBnwRY_qPoQEiDHTa6oa8=/fit-in/600x0/filters:focal(833x1250:834x1251)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/267e5783-d32e-4526-8b96-8f912cb99beb.jpg"/>
# <div class="photographer">Alain Schroeder</div>
# <div class="photo-title">Grandma Diver</div>
# </a>
# <div class="photo-tags">
# <div class="photo-tags">
# <a href="/photocontest/tags/south-korea/">#south korea</a>
# </div>
# </div>
# </div>
# <div class="grid-photo">
# <a class="lightbox-thumbnail" href="/photocontest/detail/the-boy-from-the-mountain/">
# <img alt="The Boy From the Mountain thumbnail" src="https://th-thumbnailer.cdn-si-edu.com/nN75w8o5hen84yj2L0LRFxs8X1Y=/fit-in/600x0/filters:focal(1600x1064:1601x1065)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/2584706d-76e0-47a5-a614-f0e9865c64e3.jpg"/>
# <div class="photographer">Vladimir Karamazov</div>
# <div class="photo-title">The Boy From the Mountain</div>
# </a>
# <div class="photo-tags">
# <div class="photo-tags">
# <a href="/photocontest/tags/boy/">#boy</a>
# <a href="/photocontest/tags/bulgaria/">#bulgaria</a>
# <a href="/photocontest/tags/house/">#house</a>
# <a href="/photocontest/tags/village/">#village</a>
# </div>
# </div>
# </div>
# <div class="grid-photo">
# <a class="lightbox-thumbnail" href="/photocontest/detail/title-attachment-hatred/">
# <img alt="Attachment and Hatred thumbnail" src="https://th-thumbnailer.cdn-si-edu.com/b1uGchxL7GooJHReYLUWXdcKFdM=/fit-in/600x0/filters:focal(2250x1496:2251x1497)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/c865361c-2451-4517-997b-9bb91f9f636e.jpg"/>
# <div class="photographer">Ye Win Nyunt</div>
# <div class="photo-title">Attachment and Hatred</div>
# </a>
# <div class="photo-tags">
# <div class="photo-tags">
# <a href="/photocontest/tags/monks/">#monks</a>
# <a href="/photocontest/tags/myanmar/">#myanmar</a>
# <a href="/photocontest/tags/people/">#people</a>
# </div>
# </div>
# </div>
# <div class="grid-photo">
# <a class="lightbox-thumbnail" href="/photocontest/detail/a-photo-of-a-kid-enjoying-the-summer-evening-playing-with-sprinklers/">
# <img alt="A Photo of a Kid Enjoying the Summer Evening Playing With Sprinklers thumbnail" src="https://th-thumbnailer.cdn-si-edu.com/A3YIPQlQzYwfRRTbOrvw06yMN_M=/fit-in/600x0/filters:focal(1315x1013:1316x1014)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/3118976e-4f49-437e-9094-6410299e90c4.jpg"/>
# <div class="photographer">Balu Gudimetla</div>
# <div class="photo-title">A Photo of a Kid Enjoying the Summer Evening Playing With Sprinklers</div>
# </a>
# <div class="photo-tags">
# <div class="photo-tags">
# <a href="/photocontest/tags/adventure/">#adventure</a>
# <a href="/photocontest/tags/family/">#family</a>
# <a href="/photocontest/tags/kids/">#kids</a>
# <a href="/photocontest/tags/massachusetts/">#massachusetts</a>
# <a href="/photocontest/tags/summer/">#summer</a>
# <a href="/photocontest/tags/water/">#water</a>
# </div>
# </div>
# </div>
# <div class="grid-photo">
# <a class="lightbox-thumbnail" href="/photocontest/detail/the-pride-of-a-nation/">
# <img alt="The Pride Of A Nation thumbnail" src="https://th-thumbnailer.cdn-si-edu.com/VfFwN2HOpw55mVwonzBplZg1zPc=/fit-in/600x0/filters:focal(1254x1949:1255x1950)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/63f87a5f-bf29-4f39-8fad-1c115353c854.jpg"/>
# <div class="photographer">Marlon Porter</div>
# <div class="photo-title">The Pride Of A Nation</div>
# </a>
# <div class="photo-tags">
# <div class="photo-tags">
# <a href="/photocontest/tags/canada/">#canada</a>
# <a href="/photocontest/tags/people/">#people</a>
# <a href="/photocontest/tags/ritual/">#ritual</a>
# </div>
# </div>
# </div>
# <div class="grid-photo"><div class="grid-ad"><div><div class="photo-contest-grid-ad ad-slot photo-contest-grid-ad" data-ad-settings="defaultPhotoContestStream" id="div-gpt-ad-chuckweasley-photocontest-stream-2"></div></div></div></div>
# <div class="grid-photo">
# <a class="lightbox-thumbnail" href="/photocontest/detail/paying-respect-at-a-george-floyd-sit-in/">
# <img alt="Paying Respect at a George Floyd Sit-In thumbnail" src="https://th-thumbnailer.cdn-si-edu.com/SEqJGPFWmXLu3Xv3BGu7vKruKps=/fit-in/600x0/filters:focal(1680x1117:1681x1118)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/9c641ed8-aa21-4f40-8226-63ef2c0da38a.jpg"/>
# <div class="photographer">Matt Stasi</div>
# <div class="photo-title">Paying Respect at a George Floyd Sit-In</div>
# </a>
# <div class="photo-tags">
# <div class="photo-tags">
# <a href="/photocontest/tags/california/">#california</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>

# %%
#finding the individual photo from the grid
photo = first_grid.find("img")
sample_image = photo.get('src')
sample_image
# Out:
# 'https://th-thumbnailer.cdn-si-edu.com/el_0tAXud0t3EpTjl2j_c5FYHFo=/fit-in/600x0/filters:focal(2732x1817:2733x1818)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/c130aa79-3045-4d87-9287-ebb3c8c322c3.jpg'

# %%
#finding the page link of the grid as well as making sure that I grab the entire link
photo_page = first_grid.find("a")
page_link = photo_page.get('href')
entire_link = "https://photocontest.smithsonianmag.com" + page_link
entire_link
# Out:
# 'https://photocontest.smithsonianmag.com/photocontest/detail/crabeater-seals/'

# %%
#Locating the photographer name
finding_stuff = first_grid.find_all("div")
finding_stuff[0]
# Out:
# <div class="photographer">Florian Ledoux</div>

# %%
#Narrowing the photographer name using .contents
photographer = finding_stuff[0]
sample_photographer = photographer.contents[0]
sample_photographer
# Out:
# 'Florian Ledoux'

# %%
#similar process like the name but with the title of the photo using .contents
photo_title = finding_stuff[1]
sample_title = photo_title.contents[0]
sample_title
# Out:
# 'Crabeater Seals'

# %%
#Narrowing the phototags by finding all with the attribute 'a'
photo_tags = finding_stuff[2]
finding_tag = photo_tags.find_all("a")
all_tags = []
#forloop created a list of all the tags and the ', '.join went through each element of list and seperated it with commas
for tag in finding_tag:
    all_tags.append(tag.contents[0])
', '.join(all_tags)
# Out:
# '#antarctica, #ice, #nature, #seal, #wildlife'

# %%
#Creating my first example list of Natural world using a forloop that contains my previous instructions for a single image. This will iterate over every image in the first section, Natural World.

example_list = []

for image in grids:
    
    try:
        photo = image.find("img")
        sample_image = photo.get('src')

        photo_page = image.find("a")
        page_link = photo_page.get('href')
        entire_link = "https://photocontest.smithsonianmag.com" + page_link

        finding_stuff = image.find_all("div")
        photographer = finding_stuff[0]
        sample_photographer = photographer.contents[0]

        photo_title = finding_stuff[1]
        sample_title = photo_title.contents[0]

        photo_tags = finding_stuff[2]
        finding_tag = photo_tags.find_all("a")
        all_tags = []
        for tag in finding_tag:
            all_tags.append(tag.contents[0])
        ', '.join(all_tags)

        row_data = [sample_image, entire_link, sample_photographer, sample_title, all_tags]
        example_list.append(row_data)
    except:
        continue
        
example_list
# Out:
# [['https://th-thumbnailer.cdn-si-edu.com/el_0tAXud0t3EpTjl2j_c5FYHFo=/fit-in/600x0/filters:focal(2732x1817:2733x1818)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/c130aa79-3045-4d87-9287-ebb3c8c322c3.jpg',
#   'https://photocontest.smithsonianmag.com/photocontest/detail/crabeater-seals/',
#   'Florian Ledoux',
#   'Crabeater Seals',
#   ['#antarctica', '#ice', '#nature', '#seal', '#wildlife']],
#  ['https://th-thumbnailer.cdn-si-edu.com/pFvOhv9r6ieQjCrixRLQUQ5ctmo=/fit-in/600x0/filters:focal(1000x750:1001x751)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/ded5bc33-a7ab-4558-b33a-a978b2eb4273.jpg',
#   'https://photocontest.smithsonianmag.com/photocontest/detail/turtle-19/',
#   'Galice Hoarau',
#   'Turtle',
#   ['#indonesia', '#reef', '#turtle']],
#  ['https://th-thumbnailer.cdn-si-edu.com/BFarV8TaHBkTDTQAvPJCwZVw1EI=/fit-in/600x0/filters:focal(1700x1054:1701x1055)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/04437246-243e-459e-bcde-fea5d39b8b70.jpg',
#   'https://photocontest.smithsonianmag.com/photocontest/detail/walrus-with-baby/',
#   'Gueorgui Petkov',
#   'Walrus With Baby',
#   ['#arctic', '#wildlife']],
#  ['https://th-thumbnailer.cdn-si-edu.com/yk4spV5F7hW_S6lUsKCxcDH7RMs=/fit-in/600x0/filters:focal(1500x975:1501x976)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/539bf07e-7be9-41b6-8e91-95d91c08cf8b.jpg',
#   'https://photocontest.smithsonianmag.com/photocontest/detail/goodbye-family/',
#   'Vladimir Karamazov',
#   'Goodbye Family',
#   ['#bulgaria', '#snail']],
#  ['https://th-thumbnailer.cdn-si-edu.com/FD8Dhg1H2Ju5nfSp2gU-TrJa-0U=/fit-in/600x0/filters:focal(2661x712:2662x713)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/5a0c3c0f-1851-4e30-b258-c8b02faaa7b9.jpg',
#   'https://photocontest.smithsonianmag.com/photocontest/detail/whale-tail-6/',
#   'John Comisky',
#   'Whale Tail',
#   ['#antarctica']],
#  ['https://th-thumbnailer.cdn-si-edu.com/yQmiLoUEZNa4NyR4lISYHkUgeC0=/fit-in/600x0/filters:focal(2736x1819:2737x1820)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/d07245cc-6d8e-418f-979a-170d104d05c9.jpg',
#   'https://photocontest.smithsonianmag.com/photocontest/detail/unsung-warrior/',
#   'Chandrashekhar Shirur',
#   'Unsung Warrior',
#   ['#india', '#reptile', '#wildlife']],
#  ['https://th-thumbnailer.cdn-si-edu.com/GXYzus6IAHK_aBa940pXjY0RLzM=/fit-in/600x0/filters:focal(1551x2326:1552x2327)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/11c798f3-8491-4f23-9e49-be049fcfe174.jpg',
#   'https://photocontest.smithsonianmag.com/photocontest/detail/robber-fly-with-dew/',
#   'Frank Klein',
#   'Robber Fly With Dew',
#   ['#texas']],
#  ['https://th-thumbnailer.cdn-si-edu.com/x4iUB1YETPiSzchfptYgQFi8l8I=/fit-in/600x0/filters:focal(1800x1350:1801x1351)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/75ccc8f8-09b2-475d-803f-42d0ca48757f.jpg',
#   'https://photocontest.smithsonianmag.com/photocontest/detail/light-and-rain-1/',
#   'Andro Loria',
#   'Light and Rain',
#   ['#highlands', '#iceland', '#landscape', '#weather']],
#  ['https://th-thumbnailer.cdn-si-edu.com/qGEPde6vf3ZA-qpkzSe7ud1lmH4=/fit-in/600x0/filters:focal(1000x905:1001x906)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/77c57a42-e64a-4e38-a2ae-8c1086065042.jpg',
#   'https://photocontest.smithsonianmag.com/photocontest/detail/noble-1/',
#   'Ly Dang',
#   'At the Helm',
#   ['#animal', '#baboon', '#ethiopia', '#monkey', '#wildlife']],
#  ['https://th-thumbnailer.cdn-si-edu.com/G65wHhF668ZivXtQfpk3g-1tYOs=/fit-in/600x0/filters:focal(1000x800:1001x801)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/24d46b67-7858-473b-ab31-d66c429975f2.jpg',
#   'https://photocontest.smithsonianmag.com/photocontest/detail/the-giraffe-and-the-roller/',
#   'Yaron Schmid',
#   'The Giraffe and the Roller',
#   ['#bird', '#giraffe', '#kenya', '#nature', '#safari', '#wildlife']]]

# %%
#Here I create a CSV file with corresponding headers and a for loop that assigns each element in test_list to a new row
f = csv.writer(open('Natural_World.csv', 'w'))

headers = ["Image Link", "Page Link", "Photographer", "Photo Title", "Hashtags"]

f.writerow(headers)

for row in example_list:
    f.writerow(row)

# %%
#Here I create an example data frame of my first grid structure (Natural World) to see what it would look like
import pandas as pd

exdf = pd.DataFrame(example_list, columns=headers)

exdf
# Out:
#                                           Image Link  \
# 0  https://th-thumbnailer.cdn-si-edu.com/el_0tAXu...
# 1  https://th-thumbnailer.cdn-si-edu.com/pFvOhv9r...
# 2  https://th-thumbnailer.cdn-si-edu.com/BFarV8Ta...
# 3  https://th-thumbnailer.cdn-si-edu.com/yk4spV5F...
# 4  https://th-thumbnailer.cdn-si-edu.com/FD8Dhg1H...
# 5  https://th-thumbnailer.cdn-si-edu.com/yQmiLoUE...
# 6  https://th-thumbnailer.cdn-si-edu.com/GXYzus6I...
# 7  https://th-thumbnailer.cdn-si-edu.com/x4iUB1YE...
# 8  https://th-thumbnailer.cdn-si-edu.com/qGEPde6v...
# 9  https://th-thumbnailer.cdn-si-edu.com/G65wHhF6...
#
#                                            Page Link           Photographer  \
# 0  https://photocontest.smithsonianmag.com/photoc...         Florian Ledoux
# 1  https://photocontest.smithsonianmag.com/photoc...          Galice Hoarau
# 2  https://photocontest.smithsonianmag.com/photoc...        Gueorgui Petkov
# 3  https://photocontest.smithsonianmag.com/photoc...     Vladimir Karamazov
# 4  https://photocontest.smithsonianmag.com/photoc...           John Comisky
# 5  https://photocontest.smithsonianmag.com/photoc...  Chandrashekhar Shirur
# 6  https://photocontest.smithsonianmag.com/photoc...            Frank Klein
# 7  https://photocontest.smithsonianmag.com/photoc...            Andro Loria
# 8  https://photocontest.smithsonianmag.com/photoc...                Ly Dang
# 9  https://photocontest.smithsonianmag.com/photoc...           Yaron Schmid
#
#                   Photo Title  \
# 0             Crabeater Seals
# 1                      Turtle
# 2            Walrus With Baby
# 3              Goodbye Family
# 4                  Whale Tail
# 5              Unsung Warrior
# 6         Robber Fly With Dew
# 7              Light and Rain
# 8                 At the Helm
# 9  The Giraffe and the Roller
#
#                                             Hashtags
# 0     [#antarctica, #ice, #nature, #seal, #wildlife]
# 1                       [#indonesia, #reef, #turtle]
# 2                               [#arctic, #wildlife]
# 3                                [#bulgaria, #snail]
# 4                                      [#antarctica]
# 5                      [#india, #reptile, #wildlife]
# 6                                           [#texas]
# 7       [#highlands, #iceland, #landscape, #weather]
# 8  [#animal, #baboon, #ethiopia, #monkey, #wildlife]
# 9  [#bird, #giraffe, #kenya, #nature, #safari, #w...

# %%
#Here I start on my next grid structure (people) by identifying the group of tags that I want isolated. In this case, I am taking the second group by using index 1.
people = group[1]
people
# Out:
# <section class="winners-category">
# <h3>PEOPLE</h3>
# <div class="photo-grid-photos" id="photoGridPhotos">
# <div class="photo-container" id="photoContainer1">
# <div class="grid-photo">
# <a class="lightbox-thumbnail" href="/photocontest/detail/proud-7/">
# <img alt="Nilima's Challenge thumbnail" src="https://th-thumbnailer.cdn-si-edu.com/HA-WGl4U_s6qrJwGEpgHQ3jSjs4=/fit-in/600x0/filters:focal(750x1001:751x1002)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/9f4a977a-cc98-455c-90bb-79e69d85640c.jpg"/>
# <div class="photographer">Mauro De Bettio</div>
# <div class="photo-title">Nilima's Challenge</div>
# </a>
# <div class="photo-tags">
# <div class="photo-tags">
# <a href="/photocontest/tags/bangladesh/">#bangladesh</a>
# </div>
# </div>
# </div>
# <div class="grid-photo">
# <a class="lightbox-thumbnail" href="/photocontest/detail/once-with-the-earth/">
# <img alt="Once With the Earth thumbnail" src="https://th-thumbnailer.cdn-si-edu.com/ETSl48rPSIqy8AG9-CyJhy-1RJk=/fit-in/600x0/filters:focal(750x1001:751x1002)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/b96e86ac-5110-4b11-abc5-db6e7cdc4d4d.jpg"/>
# <div class="photographer">Mauro De Bettio</div>
# <div class="photo-title">Once With the Earth</div>
# </a>
# <div class="photo-tags">
# <div class="photo-tags">
# <a href="/photocontest/tags/ethiopia/">#ethiopia</a>
# </div>
# </div>
# </div>
# <div class="grid-photo">
# <a class="lightbox-thumbnail" href="/photocontest/detail/at-the-brink-of-desperation-a-covid-19-story-from-bergamo/">
# <img alt="At the Brink of Desperation thumbnail" src="https://th-thumbnailer.cdn-si-edu.com/RdPs5ezbJjjmbZHYd1lRcjconLQ=/fit-in/600x0/filters:focal(1500x998:1501x999)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/22e2dc83-1c20-40c6-8c57-5693514f1d21.jpg"/>
# <div class="photographer">Mauro Scattolini</div>
# <div class="photo-title">At the Brink of Desperation</div>
# </a>
# <div class="photo-tags">
# <div class="photo-tags">
# <a href="/photocontest/tags/italy/">#italy</a>
# <a href="/photocontest/tags/people/">#people</a>
# </div>
# </div>
# </div>
# <div class="grid-photo">
# <a class="lightbox-thumbnail" href="/photocontest/detail/alms-1/">
# <img alt="Alms thumbnail" src="https://th-thumbnailer.cdn-si-edu.com/aN1NXXxK_t58yrvfVvROqFAYxyw=/fit-in/600x0/filters:focal(1000x665:1001x666)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/2f15d914-516b-4f39-bb39-9087a025719c.jpg"/>
# <div class="photographer">Sarah Wouters</div>
# <div class="photo-title">Alms</div>
# </a>
# <div class="photo-tags">
# <div class="photo-tags">
# <a href="/photocontest/tags/culture/">#culture</a>
# <a href="/photocontest/tags/thailand/">#thailand</a>
# </div>
# </div>
# </div>
# <div class="grid-photo">
# <a class="lightbox-thumbnail" href="/photocontest/detail/grandma-divers-10/">
# <img alt="Grandma Diver thumbnail" src="https://th-thumbnailer.cdn-si-edu.com/I5PwvaXBnwRY_qPoQEiDHTa6oa8=/fit-in/600x0/filters:focal(833x1250:834x1251)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/267e5783-d32e-4526-8b96-8f912cb99beb.jpg"/>
# <div class="photographer">Alain Schroeder</div>
# <div class="photo-title">Grandma Diver</div>
# </a>
# <div class="photo-tags">
# <div class="photo-tags">
# <a href="/photocontest/tags/south-korea/">#south korea</a>
# </div>
# </div>
# </div>
# <div class="grid-photo">
# <a class="lightbox-thumbnail" href="/photocontest/detail/the-boy-from-the-mountain/">
# <img alt="The Boy From the Mountain thumbnail" src="https://th-thumbnailer.cdn-si-edu.com/nN75w8o5hen84yj2L0LRFxs8X1Y=/fit-in/600x0/filters:focal(1600x1064:1601x1065)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/2584706d-76e0-47a5-a614-f0e9865c64e3.jpg"/>
# <div class="photographer">Vladimir Karamazov</div>
# <div class="photo-title">The Boy From the Mountain</div>
# </a>
# <div class="photo-tags">
# <div class="photo-tags">
# <a href="/photocontest/tags/boy/">#boy</a>
# <a href="/photocontest/tags/bulgaria/">#bulgaria</a>
# <a href="/photocontest/tags/house/">#house</a>
# <a href="/photocontest/tags/village/">#village</a>
# </div>
# </div>
# </div>
# <div class="grid-photo">
# <a class="lightbox-thumbnail" href="/photocontest/detail/title-attachment-hatred/">
# <img alt="Attachment and Hatred thumbnail" src="https://th-thumbnailer.cdn-si-edu.com/b1uGchxL7GooJHReYLUWXdcKFdM=/fit-in/600x0/filters:focal(2250x1496:2251x1497)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/c865361c-2451-4517-997b-9bb91f9f636e.jpg"/>
# <div class="photographer">Ye Win Nyunt</div>
# <div class="photo-title">Attachment and Hatred</div>
# </a>
# <div class="photo-tags">
# <div class="photo-tags">
# <a href="/photocontest/tags/monks/">#monks</a>
# <a href="/photocontest/tags/myanmar/">#myanmar</a>
# <a href="/photocontest/tags/people/">#people</a>
# </div>
# </div>
# </div>
# <div class="grid-photo">
# <a class="lightbox-thumbnail" href="/photocontest/detail/a-photo-of-a-kid-enjoying-the-summer-evening-playing-with-sprinklers/">
# <img alt="A Photo of a Kid Enjoying the Summer Evening Playing With Sprinklers thumbnail" src="https://th-thumbnailer.cdn-si-edu.com/A3YIPQlQzYwfRRTbOrvw06yMN_M=/fit-in/600x0/filters:focal(1315x1013:1316x1014)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/3118976e-4f49-437e-9094-6410299e90c4.jpg"/>
# <div class="photographer">Balu Gudimetla</div>
# <div class="photo-title">A Photo of a Kid Enjoying the Summer Evening Playing With Sprinklers</div>
# </a>
# <div class="photo-tags">
# <div class="photo-tags">
# <a href="/photocontest/tags/adventure/">#adventure</a>
# <a href="/photocontest/tags/family/">#family</a>
# <a href="/photocontest/tags/kids/">#kids</a>
# <a href="/photocontest/tags/massachusetts/">#massachusetts</a>
# <a href="/photocontest/tags/summer/">#summer</a>
# <a href="/photocontest/tags/water/">#water</a>
# </div>
# </div>
# </div>
# <div class="grid-photo">
# <a class="lightbox-thumbnail" href="/photocontest/detail/the-pride-of-a-nation/">
# <img alt="The Pride Of A Nation thumbnail" src="https://th-thumbnailer.cdn-si-edu.com/VfFwN2HOpw55mVwonzBplZg1zPc=/fit-in/600x0/filters:focal(1254x1949:1255x1950)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/63f87a5f-bf29-4f39-8fad-1c115353c854.jpg"/>
# <div class="photographer">Marlon Porter</div>
# <div class="photo-title">The Pride Of A Nation</div>
# </a>
# <div class="photo-tags">
# <div class="photo-tags">
# <a href="/photocontest/tags/canada/">#canada</a>
# <a href="/photocontest/tags/people/">#people</a>
# <a href="/photocontest/tags/ritual/">#ritual</a>
# </div>
# </div>
# </div>
# <div class="grid-photo"><div class="grid-ad"><div><div class="photo-contest-grid-ad ad-slot photo-contest-grid-ad" data-ad-settings="defaultPhotoContestStream" id="div-gpt-ad-chuckweasley-photocontest-stream-2"></div></div></div></div>
# <div class="grid-photo">
# <a class="lightbox-thumbnail" href="/photocontest/detail/paying-respect-at-a-george-floyd-sit-in/">
# <img alt="Paying Respect at a George Floyd Sit-In thumbnail" src="https://th-thumbnailer.cdn-si-edu.com/SEqJGPFWmXLu3Xv3BGu7vKruKps=/fit-in/600x0/filters:focal(1680x1117:1681x1118)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/9c641ed8-aa21-4f40-8226-63ef2c0da38a.jpg"/>
# <div class="photographer">Matt Stasi</div>
# <div class="photo-title">Paying Respect at a George Floyd Sit-In</div>
# </a>
# <div class="photo-tags">
# <div class="photo-tags">
# <a href="/photocontest/tags/california/">#california</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>

# %%
#I then continue narrowing down until I reach the first image of the second grid structure that I want.
second_grids = people.find_all(class_ ="grid-photo")

one_grid = second_grids[0]
one_grid
# Out:
# <div class="grid-photo">
# <a class="lightbox-thumbnail" href="/photocontest/detail/proud-7/">
# <img alt="Nilima's Challenge thumbnail" src="https://th-thumbnailer.cdn-si-edu.com/HA-WGl4U_s6qrJwGEpgHQ3jSjs4=/fit-in/600x0/filters:focal(750x1001:751x1002)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/9f4a977a-cc98-455c-90bb-79e69d85640c.jpg"/>
# <div class="photographer">Mauro De Bettio</div>
# <div class="photo-title">Nilima's Challenge</div>
# </a>
# <div class="photo-tags">
# <div class="photo-tags">
# <a href="/photocontest/tags/bangladesh/">#bangladesh</a>
# </div>
# </div>
# </div>

# %%
#Here I create another forloop using different values that will isolate my second grid structure of people.

secondexample_list = []

for image in second_grids:
    
    try:
        photo = image.find("img")
        sample_image = photo.get('src')

        photo_page = image.find("a")
        page_link = photo_page.get('href')
        entire_link = "https://photocontest.smithsonianmag.com" + page_link

        finding_stuff = image.find_all("div")
        photographer = finding_stuff[0]
        sample_photographer = photographer.contents[0]

        photo_title = finding_stuff[1]
        sample_title = photo_title.contents[0]

        photo_tags = finding_stuff[2]
        finding_tag = photo_tags.find_all("a")
        all_tags = []
        for tag in finding_tag:
            all_tags.append(tag.contents[0])
        ', '.join(all_tags)

        row_data = [sample_image, entire_link, sample_photographer, sample_title, all_tags]
        secondexample_list.append(row_data)
    except:
        continue
        
secondexample_list
# Out:
# [['https://th-thumbnailer.cdn-si-edu.com/HA-WGl4U_s6qrJwGEpgHQ3jSjs4=/fit-in/600x0/filters:focal(750x1001:751x1002)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/9f4a977a-cc98-455c-90bb-79e69d85640c.jpg',
#   'https://photocontest.smithsonianmag.com/photocontest/detail/proud-7/',
#   'Mauro De Bettio',
#   "Nilima's Challenge",
#   ['#bangladesh']],
#  ['https://th-thumbnailer.cdn-si-edu.com/ETSl48rPSIqy8AG9-CyJhy-1RJk=/fit-in/600x0/filters:focal(750x1001:751x1002)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/b96e86ac-5110-4b11-abc5-db6e7cdc4d4d.jpg',
#   'https://photocontest.smithsonianmag.com/photocontest/detail/once-with-the-earth/',
#   'Mauro De Bettio',
#   'Once With the Earth',
#   ['#ethiopia']],
#  ['https://th-thumbnailer.cdn-si-edu.com/RdPs5ezbJjjmbZHYd1lRcjconLQ=/fit-in/600x0/filters:focal(1500x998:1501x999)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/22e2dc83-1c20-40c6-8c57-5693514f1d21.jpg',
#   'https://photocontest.smithsonianmag.com/photocontest/detail/at-the-brink-of-desperation-a-covid-19-story-from-bergamo/',
#   'Mauro Scattolini',
#   'At the Brink of Desperation',
#   ['#italy', '#people']],
#  ['https://th-thumbnailer.cdn-si-edu.com/aN1NXXxK_t58yrvfVvROqFAYxyw=/fit-in/600x0/filters:focal(1000x665:1001x666)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/2f15d914-516b-4f39-bb39-9087a025719c.jpg',
#   'https://photocontest.smithsonianmag.com/photocontest/detail/alms-1/',
#   'Sarah Wouters',
#   'Alms',
#   ['#culture', '#thailand']],
#  ['https://th-thumbnailer.cdn-si-edu.com/I5PwvaXBnwRY_qPoQEiDHTa6oa8=/fit-in/600x0/filters:focal(833x1250:834x1251)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/267e5783-d32e-4526-8b96-8f912cb99beb.jpg',
#   'https://photocontest.smithsonianmag.com/photocontest/detail/grandma-divers-10/',
#   'Alain Schroeder',
#   'Grandma Diver',
#   ['#south korea']],
#  ['https://th-thumbnailer.cdn-si-edu.com/nN75w8o5hen84yj2L0LRFxs8X1Y=/fit-in/600x0/filters:focal(1600x1064:1601x1065)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/2584706d-76e0-47a5-a614-f0e9865c64e3.jpg',
#   'https://photocontest.smithsonianmag.com/photocontest/detail/the-boy-from-the-mountain/',
#   'Vladimir Karamazov',
#   'The Boy From the Mountain',
#   ['#boy', '#bulgaria', '#house', '#village']],
#  ['https://th-thumbnailer.cdn-si-edu.com/b1uGchxL7GooJHReYLUWXdcKFdM=/fit-in/600x0/filters:focal(2250x1496:2251x1497)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/c865361c-2451-4517-997b-9bb91f9f636e.jpg',
#   'https://photocontest.smithsonianmag.com/photocontest/detail/title-attachment-hatred/',
#   'Ye Win Nyunt',
#   'Attachment and Hatred',
#   ['#monks', '#myanmar', '#people']],
#  ['https://th-thumbnailer.cdn-si-edu.com/A3YIPQlQzYwfRRTbOrvw06yMN_M=/fit-in/600x0/filters:focal(1315x1013:1316x1014)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/3118976e-4f49-437e-9094-6410299e90c4.jpg',
#   'https://photocontest.smithsonianmag.com/photocontest/detail/a-photo-of-a-kid-enjoying-the-summer-evening-playing-with-sprinklers/',
#   'Balu Gudimetla',
#   'A Photo of a Kid Enjoying the Summer Evening Playing With Sprinklers',
#   ['#adventure', '#family', '#kids', '#massachusetts', '#summer', '#water']],
#  ['https://th-thumbnailer.cdn-si-edu.com/VfFwN2HOpw55mVwonzBplZg1zPc=/fit-in/600x0/filters:focal(1254x1949:1255x1950)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/63f87a5f-bf29-4f39-8fad-1c115353c854.jpg',
#   'https://photocontest.smithsonianmag.com/photocontest/detail/the-pride-of-a-nation/',
#   'Marlon Porter',
#   'The Pride Of A Nation',
#   ['#canada', '#people', '#ritual']],
#  ['https://th-thumbnailer.cdn-si-edu.com/SEqJGPFWmXLu3Xv3BGu7vKruKps=/fit-in/600x0/filters:focal(1680x1117:1681x1118)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/9c641ed8-aa21-4f40-8226-63ef2c0da38a.jpg',
#   'https://photocontest.smithsonianmag.com/photocontest/detail/paying-respect-at-a-george-floyd-sit-in/',
#   'Matt Stasi',
#   'Paying Respect at a George Floyd Sit-In',
#   ['#california']]]

# %%
#I then create another CSV file with corresponding headers and a for loop that assigns each element in test_list to a new row

f = csv.writer(open('People.csv', 'w'))

headers = ["Image Link", "Page Link", "Photographer", "Photo Title", "Hashtags"]

f.writerow(headers)

for row in secondexample_list:
    f.writerow(row)

# %%
#Here is a data frame that illustrates the category of people in a chart.
import pandas as pd

ex2df = pd.DataFrame(secondexample_list, columns=headers)

ex2df
# Out:
#                                           Image Link  \
# 0  https://th-thumbnailer.cdn-si-edu.com/HA-WGl4U...
# 1  https://th-thumbnailer.cdn-si-edu.com/ETSl48rP...
# 2  https://th-thumbnailer.cdn-si-edu.com/RdPs5ezb...
# 3  https://th-thumbnailer.cdn-si-edu.com/aN1NXXxK...
# 4  https://th-thumbnailer.cdn-si-edu.com/I5PwvaXB...
# 5  https://th-thumbnailer.cdn-si-edu.com/nN75w8o5...
# 6  https://th-thumbnailer.cdn-si-edu.com/b1uGchxL...
# 7  https://th-thumbnailer.cdn-si-edu.com/A3YIPQlQ...
# 8  https://th-thumbnailer.cdn-si-edu.com/VfFwN2HO...
# 9  https://th-thumbnailer.cdn-si-edu.com/SEqJGPFW...
#
#                                            Page Link        Photographer  \
# 0  https://photocontest.smithsonianmag.com/photoc...     Mauro De Bettio
# 1  https://photocontest.smithsonianmag.com/photoc...     Mauro De Bettio
# 2  https://photocontest.smithsonianmag.com/photoc...    Mauro Scattolini
# 3  https://photocontest.smithsonianmag.com/photoc...       Sarah Wouters
# 4  https://photocontest.smithsonianmag.com/photoc...     Alain Schroeder
# 5  https://photocontest.smithsonianmag.com/photoc...  Vladimir Karamazov
# 6  https://photocontest.smithsonianmag.com/photoc...        Ye Win Nyunt
# 7  https://photocontest.smithsonianmag.com/photoc...      Balu Gudimetla
# 8  https://photocontest.smithsonianmag.com/photoc...       Marlon Porter
# 9  https://photocontest.smithsonianmag.com/photoc...          Matt Stasi
#
#                                          Photo Title  \
# 0                                 Nilima's Challenge
# 1                                Once With the Earth
# 2                        At the Brink of Desperation
# 3                                               Alms
# 4                                      Grandma Diver
# 5                          The Boy From the Mountain
# 6                              Attachment and Hatred
# 7  A Photo of a Kid Enjoying the Summer Evening P...
# 8                              The Pride Of A Nation
# 9            Paying Respect at a George Floyd Sit-In
#
#                                             Hashtags
# 0                                      [#bangladesh]
# 1                                        [#ethiopia]
# 2                                  [#italy, #people]
# 3                              [#culture, #thailand]
# 4                                     [#south korea]
# 5                [#boy, #bulgaria, #house, #village]
# 6                        [#monks, #myanmar, #people]
# 7  [#adventure, #family, #kids, #massachusetts, #...
# 8                        [#canada, #people, #ritual]
# 9                                      [#california]

# %%
#I then repeat the process for the subsequent cells to isolate my third category of travel. 
travel = group[2]
travel
# Out:
# <section class="winners-category">
# <h3>TRAVEL</h3>
# <div class="photo-grid-photos" id="photoGridPhotos">
# <div class="photo-container" id="photoContainer1">
# <div class="grid-photo">
# <a class="lightbox-thumbnail" href="/photocontest/detail/serenity-137/">
# <img alt="Serenity thumbnail" src="https://th-thumbnailer.cdn-si-edu.com/utJov_MoR8N6__ytjRfMHBOZpvQ=/fit-in/600x0/filters:focal(2016x1512:2017x1513)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/611b3d47-0a64-4814-8f7a-be79351a1389.jpg"/>
# <div class="photographer">Ankit Sharma</div>
# <div class="photo-title">Serenity</div>
# </a>
# <div class="photo-tags">
# <div class="photo-tags">
# <a href="/photocontest/tags/india/">#india</a>
# <a href="/photocontest/tags/morning/">#morning</a>
# <a href="/photocontest/tags/people/">#people</a>
# <a href="/photocontest/tags/reflection/">#reflection</a>
# <a href="/photocontest/tags/travel/">#travel</a>
# </div>
# </div>
# </div>
# <div class="grid-photo">
# <a class="lightbox-thumbnail" href="/photocontest/detail/inside-a-hot-balloon/">
# <img alt="Colorful Work thumbnail" src="https://th-thumbnailer.cdn-si-edu.com/-D-PfFeZFiBCaA_wt9YAw2Eot94=/fit-in/600x0/filters:focal(1024x681:1025x682)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/e4faeeb8-1a6e-4008-8782-754181c79cee.jpg"/>
# <div class="photographer">Tran Tuan Viet</div>
# <div class="photo-title">Colorful Work</div>
# </a>
# <div class="photo-tags">
# <div class="photo-tags">
# <a href="/photocontest/tags/travel/">#travel</a>
# <a href="/photocontest/tags/vietnam/">#vietnam</a>
# </div>
# </div>
# </div>
# <div class="grid-photo">
# <a class="lightbox-thumbnail" href="/photocontest/detail/dance-on-the-auspicious-day-of-turmeric-festival/">
# <img alt="Dance on the Auspicious Day of the Turmeric Festival thumbnail" src="https://th-thumbnailer.cdn-si-edu.com/oHep_crZs8VYZmZUJr3_TAdVRvA=/fit-in/600x0/filters:focal(1125x748:1126x749)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/b39056d1-ed48-4753-a64a-c256930c494b.jpg"/>
# <div class="photographer">Prithwiraj Dhang</div>
# <div class="photo-title">Dance on the Auspicious Day of the Turmeric Festival</div>
# </a>
# <div class="photo-tags">
# <div class="photo-tags">
# <a href="/photocontest/tags/festival/">#festival</a>
# <a href="/photocontest/tags/india/">#india</a>
# </div>
# </div>
# </div>
# <div class="grid-photo">
# <a class="lightbox-thumbnail" href="/photocontest/detail/taekwando-8/">
# <img alt="Taekwondo thumbnail" src="https://th-thumbnailer.cdn-si-edu.com/CABmhyYs-IoSgqCzlRipwoaBQhc=/fit-in/600x0/filters:focal(1250x831:1251x832)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/c2137f1e-575e-4081-be5b-b83a17411846.jpg"/>
# <div class="photographer">Alain Schroeder</div>
# <div class="photo-title">Taekwondo</div>
# </a>
# <div class="photo-tags">
# <div class="photo-tags">
# <a href="/photocontest/tags/korea/">#korea</a>
# <a href="/photocontest/tags/north/">#north</a>
# </div>
# </div>
# </div>
# <div class="grid-photo">
# <a class="lightbox-thumbnail" href="/photocontest/detail/fishing-boat-11/">
# <img alt="Fishing Boat thumbnail" src="https://th-thumbnailer.cdn-si-edu.com/z7TERTzhLPFFw3fliN055l7-bpI=/fit-in/600x0/filters:focal(2424x1612:2425x1613)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/52ff95fe-7642-4b46-9c1e-294d2a5f7860.jpg"/>
# <div class="photographer">Phuoc Hoai Nguyen</div>
# <div class="photo-title">Fishing Boat</div>
# </a>
# <div class="photo-tags">
# <div class="photo-tags">
# <a href="/photocontest/tags/blue/">#blue</a>
# <a href="/photocontest/tags/boat/">#boat</a>
# <a href="/photocontest/tags/fishing/">#fishing</a>
# <a href="/photocontest/tags/net/">#net</a>
# <a href="/photocontest/tags/people/">#people</a>
# <a href="/photocontest/tags/sea/">#sea</a>
# <a href="/photocontest/tags/vietnam/">#vietnam</a>
# </div>
# </div>
# </div>
# <div class="grid-photo">
# <a class="lightbox-thumbnail" href="/photocontest/detail/green-clouds/">
# <img alt="Green Clouds thumbnail" src="https://th-thumbnailer.cdn-si-edu.com/puOuQJrwnHpz2OaKV3KdAE41CHE=/fit-in/600x0/filters:focal(667x1000:668x1001)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/cca64e65-91a9-469f-a36b-1008411cfc32.jpg"/>
# <div class="photographer">Viktor Lyagushkin</div>
# <div class="photo-title">Green Clouds</div>
# </a>
# <div class="photo-tags">
# <div class="photo-tags">
# <a href="/photocontest/tags/ice/">#ice</a>
# <a href="/photocontest/tags/underwater/">#underwater</a>
# </div>
# </div>
# </div>
# <div class="grid-photo">
# <a class="lightbox-thumbnail" href="/photocontest/detail/autumn-morning-at-the-american-swamps/">
# <img alt="Autumn Morning at the American Swamps thumbnail" src="https://th-thumbnailer.cdn-si-edu.com/4dIQbcqtizbOVhuV9By905te1xY=/fit-in/600x0/filters:focal(1000x635:1001x636)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/178eec8f-62cb-4af5-88b4-11bc54b449a2.jpg"/>
# <div class="photographer">Callie Chee</div>
# <div class="photo-title">Autumn Morning at the American Swamps</div>
# </a>
# <div class="photo-tags">
# <div class="photo-tags">
# <a href="/photocontest/tags/kayak/">#kayak</a>
# <a href="/photocontest/tags/sunrise/">#sunrise</a>
# </div>
# </div>
# </div>
# <div class="grid-photo">
# <a class="lightbox-thumbnail" href="/photocontest/detail/generous-russia/">
# <img alt="Generous Russia thumbnail" src="https://th-thumbnailer.cdn-si-edu.com/rX6lSleTdcF_7_SbEc80GQ1gw8I=/fit-in/600x0/filters:focal(2894x1924:2895x1925)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/10b5daa8-77c3-49d0-8153-8e88529ab473.jpeg"/>
# <div class="photographer">Olesia Kim</div>
# <div class="photo-title">Generous Russia</div>
# </a>
# <div class="photo-tags">
# <div class="photo-tags">
# <a href="/photocontest/tags/food/">#food</a>
# <a href="/photocontest/tags/hood/">#hood</a>
# <a href="/photocontest/tags/meal/">#meal</a>
# </div>
# </div>
# </div>
# <div class="grid-photo">
# <a class="lightbox-thumbnail" href="/photocontest/detail/in-spite-of-everything/">
# <img alt="In Spite of Everything thumbnail" src="https://th-thumbnailer.cdn-si-edu.com/b7OuuIZAX6JFl8DtcIPeYp7Pr6w=/fit-in/600x0/filters:focal(3075x2045:3076x2046)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/86142878-8187-474d-8016-5f0bfb0ff760.jpg"/>
# <div class="photographer">Marco Campi</div>
# <div class="photo-title">In Spite of Everything</div>
# </a>
# <div class="photo-tags">
# <div class="photo-tags">
# <a href="/photocontest/tags/flood/">#flood</a>
# <a href="/photocontest/tags/italy/">#italy</a>
# <a href="/photocontest/tags/square/">#square</a>
# <a href="/photocontest/tags/tide/">#tide</a>
# <a href="/photocontest/tags/venice/">#venice</a>
# </div>
# </div>
# </div>
# <div class="grid-photo"><div class="grid-ad"><div><div class="photo-contest-grid-ad ad-slot photo-contest-grid-ad" data-ad-settings="defaultPhotoContestStream" id="div-gpt-ad-chuckweasley-photocontest-stream-3"></div></div></div></div>
# <div class="grid-photo">
# <a class="lightbox-thumbnail" href="/photocontest/detail/the-far-away/">
# <img alt="The Far Away thumbnail" src="https://th-thumbnailer.cdn-si-edu.com/2jxx2BpmA2Kkl9_9HfSi9lyiGNA=/fit-in/600x0/filters:focal(1781x1282:1782x1283)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/451cff38-2332-42fe-b130-1095c6e460df.jpg"/>
# <div class="photographer">Christopher Michel</div>
# <div class="photo-title">The Far Away</div>
# </a>
# <div class="photo-tags">
# <div class="photo-tags">
# <a href="/photocontest/tags/antarctica/">#antarctica</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>

# %%
third_grids = travel.find_all(class_ ="grid-photo")

thefirst_grid = third_grids[0]
thefirst_grid
# Out:
# <div class="grid-photo">
# <a class="lightbox-thumbnail" href="/photocontest/detail/serenity-137/">
# <img alt="Serenity thumbnail" src="https://th-thumbnailer.cdn-si-edu.com/utJov_MoR8N6__ytjRfMHBOZpvQ=/fit-in/600x0/filters:focal(2016x1512:2017x1513)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/611b3d47-0a64-4814-8f7a-be79351a1389.jpg"/>
# <div class="photographer">Ankit Sharma</div>
# <div class="photo-title">Serenity</div>
# </a>
# <div class="photo-tags">
# <div class="photo-tags">
# <a href="/photocontest/tags/india/">#india</a>
# <a href="/photocontest/tags/morning/">#morning</a>
# <a href="/photocontest/tags/people/">#people</a>
# <a href="/photocontest/tags/reflection/">#reflection</a>
# <a href="/photocontest/tags/travel/">#travel</a>
# </div>
# </div>
# </div>

# %%
thirdexample_list = []

for image in third_grids:
    
    try:
        photo = image.find("img")
        sample_image = photo.get('src')

        photo_page = image.find("a")
        page_link = photo_page.get('href')
        entire_link = "https://photocontest.smithsonianmag.com" + page_link

        finding_stuff = image.find_all("div")
        photographer = finding_stuff[0]
        sample_photographer = photographer.contents[0]

        photo_title = finding_stuff[1]
        sample_title = photo_title.contents[0]

        photo_tags = finding_stuff[2]
        finding_tag = photo_tags.find_all("a")
        all_tags = []
        for tag in finding_tag:
            all_tags.append(tag.contents[0])
        ', '.join(all_tags)

        row_data = [sample_image, entire_link, sample_photographer, sample_title, all_tags]
        thirdexample_list.append(row_data)
    except:
        continue
        
thirdexample_list
# Out:
# [['https://th-thumbnailer.cdn-si-edu.com/utJov_MoR8N6__ytjRfMHBOZpvQ=/fit-in/600x0/filters:focal(2016x1512:2017x1513)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/611b3d47-0a64-4814-8f7a-be79351a1389.jpg',
#   'https://photocontest.smithsonianmag.com/photocontest/detail/serenity-137/',
#   'Ankit Sharma',
#   'Serenity',
#   ['#india', '#morning', '#people', '#reflection', '#travel']],
#  ['https://th-thumbnailer.cdn-si-edu.com/-D-PfFeZFiBCaA_wt9YAw2Eot94=/fit-in/600x0/filters:focal(1024x681:1025x682)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/e4faeeb8-1a6e-4008-8782-754181c79cee.jpg',
#   'https://photocontest.smithsonianmag.com/photocontest/detail/inside-a-hot-balloon/',
#   'Tran Tuan Viet',
#   'Colorful Work',
#   ['#travel', '#vietnam']],
#  ['https://th-thumbnailer.cdn-si-edu.com/oHep_crZs8VYZmZUJr3_TAdVRvA=/fit-in/600x0/filters:focal(1125x748:1126x749)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/b39056d1-ed48-4753-a64a-c256930c494b.jpg',
#   'https://photocontest.smithsonianmag.com/photocontest/detail/dance-on-the-auspicious-day-of-turmeric-festival/',
#   'Prithwiraj Dhang',
#   'Dance on the Auspicious Day of the Turmeric Festival',
#   ['#festival', '#india']],
#  ['https://th-thumbnailer.cdn-si-edu.com/CABmhyYs-IoSgqCzlRipwoaBQhc=/fit-in/600x0/filters:focal(1250x831:1251x832)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/c2137f1e-575e-4081-be5b-b83a17411846.jpg',
#   'https://photocontest.smithsonianmag.com/photocontest/detail/taekwando-8/',
#   'Alain Schroeder',
#   'Taekwondo',
#   ['#korea', '#north']],
#  ['https://th-thumbnailer.cdn-si-edu.com/z7TERTzhLPFFw3fliN055l7-bpI=/fit-in/600x0/filters:focal(2424x1612:2425x1613)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/52ff95fe-7642-4b46-9c1e-294d2a5f7860.jpg',
#   'https://photocontest.smithsonianmag.com/photocontest/detail/fishing-boat-11/',
#   'Phuoc Hoai Nguyen',
#   'Fishing Boat',
#   ['#blue', '#boat', '#fishing', '#net', '#people', '#sea', '#vietnam']],
#  ['https://th-thumbnailer.cdn-si-edu.com/puOuQJrwnHpz2OaKV3KdAE41CHE=/fit-in/600x0/filters:focal(667x1000:668x1001)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/cca64e65-91a9-469f-a36b-1008411cfc32.jpg',
#   'https://photocontest.smithsonianmag.com/photocontest/detail/green-clouds/',
#   'Viktor Lyagushkin',
#   'Green Clouds',
#   ['#ice', '#underwater']],
#  ['https://th-thumbnailer.cdn-si-edu.com/4dIQbcqtizbOVhuV9By905te1xY=/fit-in/600x0/filters:focal(1000x635:1001x636)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/178eec8f-62cb-4af5-88b4-11bc54b449a2.jpg',
#   'https://photocontest.smithsonianmag.com/photocontest/detail/autumn-morning-at-the-american-swamps/',
#   'Callie Chee',
#   'Autumn Morning at the American Swamps',
#   ['#kayak', '#sunrise']],
#  ['https://th-thumbnailer.cdn-si-edu.com/rX6lSleTdcF_7_SbEc80GQ1gw8I=/fit-in/600x0/filters:focal(2894x1924:2895x1925)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/10b5daa8-77c3-49d0-8153-8e88529ab473.jpeg',
#   'https://photocontest.smithsonianmag.com/photocontest/detail/generous-russia/',
#   'Olesia Kim',
#   'Generous Russia',
#   ['#food', '#hood', '#meal']],
#  ['https://th-thumbnailer.cdn-si-edu.com/b7OuuIZAX6JFl8DtcIPeYp7Pr6w=/fit-in/600x0/filters:focal(3075x2045:3076x2046)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/86142878-8187-474d-8016-5f0bfb0ff760.jpg',
#   'https://photocontest.smithsonianmag.com/photocontest/detail/in-spite-of-everything/',
#   'Marco Campi',
#   'In Spite of Everything',
#   ['#flood', '#italy', '#square', '#tide', '#venice']],
#  ['https://th-thumbnailer.cdn-si-edu.com/2jxx2BpmA2Kkl9_9HfSi9lyiGNA=/fit-in/600x0/filters:focal(1781x1282:1782x1283)/https://tf-cmsv2-photocontest-smithsonianmag-prod-approved.s3.amazonaws.com/451cff38-2332-42fe-b130-1095c6e460df.jpg',
#   'https://photocontest.smithsonianmag.com/photocontest/detail/the-far-away/',
#   'Christopher Michel',
#   'The Far Away',
#   ['#antarctica']]]

# %%
f = csv.writer(open('Travel.csv', 'w'))

headers = ["Image Link", "Page Link", "Photographer", "Photo Title", "Hashtags"]

f.writerow(headers)

for row in thirdexample_list:
    f.writerow(row)

# %%
import pandas as pd

ex3df = pd.DataFrame(thirdexample_list, columns=headers)

ex3df
# Out:
#                                           Image Link  \
# 0  https://th-thumbnailer.cdn-si-edu.com/utJov_Mo...
# 1  https://th-thumbnailer.cdn-si-edu.com/-D-PfFeZ...
# 2  https://th-thumbnailer.cdn-si-edu.com/oHep_crZ...
# 3  https://th-thumbnailer.cdn-si-edu.com/CABmhyYs...
# 4  https://th-thumbnailer.cdn-si-edu.com/z7TERTzh...
# 5  https://th-thumbnailer.cdn-si-edu.com/puOuQJrw...
# 6  https://th-thumbnailer.cdn-si-edu.com/4dIQbcqt...
# 7  https://th-thumbnailer.cdn-si-edu.com/rX6lSleT...
# 8  https://th-thumbnailer.cdn-si-edu.com/b7OuuIZA...
# 9  https://th-thumbnailer.cdn-si-edu.com/2jxx2Bpm...
#
#                                            Page Link        Photographer  \
# 0  https://photocontest.smithsonianmag.com/photoc...        Ankit Sharma
# 1  https://photocontest.smithsonianmag.com/photoc...      Tran Tuan Viet
# 2  https://photocontest.smithsonianmag.com/photoc...    Prithwiraj Dhang
# 3  https://photocontest.smithsonianmag.com/photoc...     Alain Schroeder
# 4  https://photocontest.smithsonianmag.com/photoc...   Phuoc Hoai Nguyen
# 5  https://photocontest.smithsonianmag.com/photoc...   Viktor Lyagushkin
# 6  https://photocontest.smithsonianmag.com/photoc...         Callie Chee
# 7  https://photocontest.smithsonianmag.com/photoc...          Olesia Kim
# 8  https://photocontest.smithsonianmag.com/photoc...         Marco Campi
# 9  https://photocontest.smithsonianmag.com/photoc...  Christopher Michel
#
#                                          Photo Title  \
# 0                                           Serenity
# 1                                      Colorful Work
# 2  Dance on the Auspicious Day of the Turmeric Fe...
# 3                                          Taekwondo
# 4                                       Fishing Boat
# 5                                       Green Clouds
# 6              Autumn Morning at the American Swamps
# 7                                    Generous Russia
# 8                             In Spite of Everything
# 9                                       The Far Away
#
#                                             Hashtags
# 0  [#india, #morning, #people, #reflection, #travel]
# 1                                [#travel, #vietnam]
# 2                                [#festival, #india]
# 3                                   [#korea, #north]
# 4  [#blue, #boat, #fishing, #net, #people, #sea, ...
# 5                                [#ice, #underwater]
# 6                                 [#kayak, #sunrise]
# 7                              [#food, #hood, #meal]
# 8          [#flood, #italy, #square, #tide, #venice]
# 9                                      [#antarctica]

# %% [markdown]
# # Final Project Next Steps
#
# Our work in this lab is designed to lay the foundation and serve as a springboard for final project work. Specifically, Q4, Q10, and Q13 ask you to develop an outline for web scraping programs using `BeautifulSoup` and `pd.read_html()`.
#
# Those questions (and other work for this lab) are the starting place for the final project.
#
# The final project for this course involves a web-scraping project written in Python. Specifically, the final project allows you to select a web page (or web pages) and write a Python program (or programs) that downloads select content from that web page as a plain-text file (`CSV`, `TXT`, etc). That content could be paragraphs of text, tables of data, etc.
#
# Successful final projects will include two main components:
# - a well-documented, working Python program written in Jupyter Notebooks
# - a written reflection (minimum 300 words) that documents how you approached the final project/what you wanted to accomplish via the final project, resources consulted, how you handled challenges you encountered, key takeaways, etc.
#
# That reflection can come at the end of the Jupyter Notebook or be embedded throughout the Jupyter Notebook, if you want to approach authoring the notebook as a type of tutorial or "report".
#
# Expect to spend at least 10 hours working on the final project. That includes brainstorming, meeting with instructor/TAs, in-class work time, etc. If you’re working on a project that is not going to take that much time, think about how to add complexity or take on another smaller scale project.
# - Contact the instructor with questions.
#
# **So where to start?**
#
# The instructor and TAs are going to move quickly on getting you feedback on this lab.
#
# But your work in Q4, Q10, and Q13 should be the starting place for how you think about and approach the final project.
#
# Specifically, think about the kinds of web content you were able to scrape for these questions and how you might further develop, refine, or expand your work.
#
# For example, these questions asked you to develop an outline for specific types of webscraping programs.
# - One next step for the final project could be selecting 1-2 of these programs and further developing or refining the code.
# - Another next step (especially if you were able to develop working programs for these questions) is to think about how you could expand or extend these workflows to multiple web pages or other web data sources.
# - A third option for next steps would involve thinking expansively about how you could apply the concepts and approaches covered in this lab to a different type of data source/structure.
#
# So in the interim, as you're waiting for feedback on this lab, think about where you could go next with expanding and extending your work in this lab, and start to flesh out or develop some of your own ideas about where you put your time and effort as you work on the final project.
#
# **Final project timeline**
# - Week #14 (11/23): In-class work time
# - Week #15 (11/30, 12/2):
#   * Initial version of lab due end of day Tuesday 11/30
#   * In-class work time both days
# - By end of Week #15: Final project update/shareout due on Canvas
# - By end of day Friday 12/10 (Week #16, last week of classes/start of exam week): Final project due on Canvas by end of day
#
# Again, contact the instructor with questions.
